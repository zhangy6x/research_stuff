# %%
import numpy as np
import pandas as pd
import os
from pprint import pprint

# %%
file_path = '/Users/y9z/OneDrive - Oak Ridge National Laboratory/CG1D/SuiteReview/2020_review_documents/stats/raw_files/ICON.csv'

# %%
# ris_keys = ['type_of_reference', 'authors', 'title', 'journal_name', 'volume', 'number', 'issn', 'place_published', 'publisher', 'note', 'start_page', 'year', 'abstract', 'label', 'doi', 'url']

# %%
df = pd.read_csv(file_path)
df
# Out:
#            PID               Publication Type             Full Text  \
# 0    psi:13307                Journal Article            Restricted
# 1    psi:13221                Journal Article            Restricted
# 2    psi:16329              Proceedings Paper            Restricted
# 3    psi:16683                Journal Article            Restricted
# 4    psi:31679  Newspaper or Magazine Article            Restricted
# ..         ...                            ...                   ...
# 238  psi:28684                Journal Article  Restricted (Embargo)
# 239  psi:30121                Journal Article           Open Access
# 240  psi:32374                Journal Article           Open Access
# 241  psi:28898              Proceedings Paper           Open Access
# 242  psi:31575                Journal Article           Open Access
#
#                                              Author(s)   Editor(s)  \
# 0    Lehmann, Eberhard H.; Vontobel, Peter; Hassane...         NaN
# 1    Kühne, Guido; Frei, Gabriel; Lehmann, Eberhard...         NaN
# 2    Wagner, W.; Mesot, J.; Allenspach, P.; Kuehne,...         NaN
# 3    Hassanein, René; de Beer, Frikkie; Kardjilov, ...         NaN
# 4             Lehmann, Eberhard H.; Dangendorf, Volker         NaN
# ..                                                 ...         ...
# 238  Shafizadeh, A.; Gimmi, T.; Van Loon, L.R.; Kae...         NaN
# 239  Valsecchi, Jacopo; Strobl, Markus; Harti, Ralp...         NaN
# 240  Siegwart, M.; Manzi-Orezzoli, V.; Valsecchi, J...         NaN
# 241  Carminati, Chiara; Boillat, Pierre; Laemmlein,...  Garbe, Ulf
# 242  Siegwart, M.; Huang, F.; Cochet, M.; Schmidt, ...         NaN
#
#      Publication Year                                              Title  \
# 0                2005  Neutron tomography as tool for applied researc...
# 1                2005  CNR - the new beamline for cold neutron imagin...
# 2                2006  The Swiss spallation neutron source SINQ-devel...
# 3                2006  Scattering correction algorithm for neutron ra...
# 4                2006  Neutronen-Imaging. Eine Alternative zum normal...
# ..                ...                                                ...
# 238              2020  Time-resolved porosity changes at cement-clay ...
# 239              2020  Characterization of oriented microstructures t...
# 240              2020  Operando visualization of water distribution i...
# 241              2020  Effect of scattering correction in neutron ima...
# 242              2020  Spatially resolved analysis of freezing during...
#
#                             Journal Title (Book Title)   Volume  Issue  ...  \
# 0                      Advances in Solid State Physics       45    NaN  ...
# 1    Nuclear Instruments and Methods in Physics Res...      542  3-Jan  ...
# 2    Proceedings of the international conference on...  378-380    NaN  ...
# 3                          Physica B: Condensed Matter  385-386    NaN  ...
# 4    Bulletin SEV/VSE, Fachzeitschrift und Verbands...       97     11  ...
# ..                                                 ...      ...    ...  ...
# 238                       Cement and Concrete Research      127    NaN  ...
# 239                             Communications Physics        3      1  ...
# 240             Journal of the Electrochemical Society      167      6  ...
# 241                       Neutron radiography. WCNR-11       15    NaN  ...
# 242             Journal of the Electrochemical Society      167      6  ...
#
#                   ISBN        WoS ID           Scopus ID  PubMed ID  \
# 0                  NaN           NaN  2-s2.0-34047133772        NaN
# 1                  NaN  2.292950e+11  2-s2.0-17644396638        NaN
# 2                  NaN  2.433410e+11  2-s2.0-33751222272        NaN
# 3                  NaN           NaN  2-s2.0-33751232346        NaN
# 4                  NaN           NaN                 NaN        NaN
# ..                 ...           ...                 ...        ...
# 238                NaN  5.014140e+11  2-s2.0-85074655629        NaN
# 239                NaN           NaN                 NaN        NaN
# 240                NaN  5.228810e+11  2-s2.0-85084671274        NaN
# 241  978-1-64490-057-4           NaN                 NaN        NaN
# 242                NaN  5.228820e+11                 NaN        NaN
#
#            DUO Proposal Peer Review    Facility      Beamline  \
# 0                   NaN         Yes  SINQ; SINQ  ICON; NEUTRA
# 1                   NaN         Yes        SINQ          ICON
# 2                   NaN         NaN  SINQ; SINQ    ICON; MARS
# 3                   NaN         Yes  SINQ; SINQ  ICON; NEUTRA
# 4                   NaN          No        SINQ          ICON
# ..                  ...         ...         ...           ...
# 238                 NaN         Yes        SINQ          ICON
# 239                 NaN         Yes        SINQ          ICON
# 240                 NaN         Yes        SINQ          ICON
# 241                 NaN         Yes  SINQ; SINQ  ICON; NEUTRA
# 242  20170321; 20170978         Yes        SINQ          ICON
#
#                                               Division  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Research with Neutrons and Muons NUM; Paul Sch...
# 3    Research with Neutrons and Muons NUM; Research...
# 4                 Research with Neutrons and Muons NUM
# ..                                                 ...
# 238  Nuclear Energy and Safety NES; Nuclear Energy ...
# 239  Research with Neutrons and Muons NUM; Research...
# 240  Energy and Environment ENE; Energy and Environ...
# 241  Research with Neutrons and Muons NUM; Energy a...
# 242  Energy and Environment ENE; Energy and Environ...
#
#                                             Laboratory
# 0                                                  NaN
# 1                                                  NaN
# 2    Spallations-Neutronenquelle; Directorate; Entw...
# 3    Spallations-Neutronenquelle; Spallations-Neutr...
# 4                          Spallations-Neutronenquelle
# ..                                                 ...
# 238  Waste Management LES; Waste Management LES; Wa...
# 239  Neutron Scattering and Imaging LNS; Neutron Sc...
# 240  Electrochemistry LEC; Electrochemistry LEC; Ne...
# 241  Neutron Scattering and Imaging LNS; Electroche...
# 242  Electrochemistry LEC; Electrochemistry LEC; El...
#
# [243 rows x 26 columns]

# %%
df.to_clipboard()

# %%
df_stat = df['Publication Year'].value_counts()

# %%
df_stat.sort_index(inplace=True)

# %%
df_stat.to_clipboard()

# %%
df['Publication Type'].value_counts().to_clipboard()

# %%
df['Beamline'].value_counts().to_clipboard()
