# %%
from ImagingReso.resonance import Resonance
import pandas as pd
import numpy as np
import ImagingReso._utilities as ir_util
import pprint
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
# Load CG-1D beam shape
path_to_beam_shape = '/Users/y9z/Dropbox (ORNL)/Postdoc_Research/neutron_beam_shape/CG1D/beam_shape_cg1d.txt'
df = pd.read_csv(path_to_beam_shape, sep='\t', skiprows=0)
df.columns = ['wavelength_A', 'flux']

# %%
# Get rid of abnormal data
df.drop(df[df.wavelength_A < 0].index, inplace=True)
df.drop(df[df.flux <= 0].index, inplace=True)
df.reset_index(drop=True, inplace=True)
# Convert lambda to energy
energy_list = ir_util.angstroms_to_ev(df['wavelength_A'])
df.insert(1, 'energy_eV', energy_list)
df
# Out:
#     wavelength_A  energy_eV          flux
# 0       0.812655   0.123843  1.776169e+04
# 1       1.028404   0.077332  1.201199e+05
# 2       1.244153   0.052837  2.919421e+05
# 3       1.459902   0.038374  5.860009e+05
# 4       1.675651   0.029128  1.030660e+06
# 5       1.891400   0.022862  1.509066e+06
# 6       2.107149   0.018420  1.863847e+06
# 7       2.322899   0.015157  1.989239e+06
# 8       2.538648   0.012691  2.231573e+06
# 9       2.754397   0.010780  2.254231e+06
# 10      2.970146   0.009271  2.117908e+06
# 11      3.185895   0.008058  1.921868e+06
# 12      3.401644   0.007068  1.725260e+06
# 13      3.617393   0.006250  1.556134e+06
# 14      3.833142   0.005566  1.394662e+06
# 15      4.048891   0.004989  1.156793e+06
# 16      4.264640   0.004497  1.126788e+06
# 17      4.480389   0.004074  1.016330e+06
# 18      4.696139   0.003709  8.334823e+05
# 19      4.911888   0.003390  7.745360e+05
# 20      5.127637   0.003111  7.204620e+05
# 21      5.343386   0.002865  6.151784e+05
# 22      5.559135   0.002646  5.240242e+05
# 23      5.774884   0.002452  4.438901e+05
# 24      5.990633   0.002279  3.748091e+05
# 25      6.206382   0.002123  3.170087e+05
# 26      6.422131   0.001983  2.684945e+05
# 27      6.637880   0.001856  2.252935e+05
# 28      6.853629   0.001741  1.899357e+05
# 29      7.069379   0.001637  1.652598e+05
# ..           ...        ...           ...
# 44     10.305615   0.000770  9.856068e+03
# 45     10.521364   0.000739  7.545377e+03
# 46     10.737113   0.000709  6.609386e+03
# 47     10.952862   0.000682  4.710191e+03
# 48     11.168611   0.000656  3.710300e+03
# 49     11.384360   0.000631  2.448360e+03
# 50     11.600109   0.000608  2.126788e+03
# 51     11.815859   0.000586  1.062280e+03
# 52     12.031608   0.000565  1.862909e+03
# 53     12.247357   0.000545  2.771285e+03
# 54     12.463106   0.000527  1.904687e+03
# 55     12.678855   0.000509  2.842666e+03
# 56     12.894604   0.000492  1.178463e+03
# 57     13.110353   0.000476  7.392747e+02
# 58     13.326102   0.000461  7.855888e+02
# 59     13.541851   0.000446  1.787310e+02
# 60     13.973349   0.000419  5.113648e+02
# 61     14.189099   0.000406  8.848219e+02
# 62     14.404848   0.000394  8.028571e+02
# 63     14.620597   0.000383  1.078275e+03
# 64     14.836346   0.000372  1.106127e+02
# 65     15.052095   0.000361  1.260109e+03
# 66     15.267844   0.000351  8.664395e+02
# 67     15.483593   0.000341  1.239260e+03
# 68     15.699342   0.000332  1.170664e+03
# 69     15.915091   0.000323  8.130430e+02
# 70     16.130840   0.000314  1.207986e+02
# 71     16.346589   0.000306  2.553641e+02
# 72     16.562339   0.000298  3.654197e+02
# 73     16.778088   0.000291  5.451853e+02
#
# [74 rows x 3 columns]

# %%
# Preview the first and last energy
energy_list = list(df['energy_eV'])
_energy_min = energy_list[-1]
_energy_max = energy_list[0]
_energy_step = (_energy_max - _energy_min)/200
print("_E_min = {} (eV)\n_E_max = {} (eV)\n_E_step = {} (eV)\n".format(_energy_min, _energy_max, _energy_step))
# Out:
# _E_min = 0.00029053560401083275 (eV)
# _E_max = 0.12384313918225247 (eV)
# _E_step = 0.0006177630178912082 (eV)

# %%
_energy_max.round(5)
# Out:
# 0.12384000000000001

# %%
_energy_min.round(5)
# Out:
# 0.00029

# %%
# Determine e_max and e_min to pass
energy_min = 0.00025
energy_max = 0.12525
energy_step = (energy_max - energy_min)/200
print("E_min = {} (eV)\nE_max = {} (eV)\nE_step = {} (eV)\n".format(energy_min, energy_max, energy_step))
# Out:
# E_min = 0.00025 (eV)
# E_max = 0.12525 (eV)
# E_step = 0.000625 (eV)

# %%
# Set the energy range and step
o_reso = Resonance(energy_min=energy_min, energy_max=energy_max, energy_step=energy_step)

# %% [markdown]
# ## Sample info
# layer_1 = 'SiO2'
# wt_per_1 = 20.3%
#
# layer_2 = 'Al2O3'
# wt_per_2 = 4.6%
#
# layer_3 = 'Fe2O3'
# wt_per_3 = 3.1%
#
# layer_4 = 'CaO'
# wt_per_4 = 63.4%
#
# layer_5 = 'MgO'
# wt_per_5 = 2.3%
#
# layer_6 = 'SO3'
# wt_per_6 = 3.2%

# %%
# Input sample info
sample_thickness = 23 # mm  thickness in the beam
sample_density = 1.5 # g/cm3  total density of sample in the beam

layer_list = ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3', 'Gd']

gd_density = 0 # g/cm3
# gd_density = 0.015 # g/cm3
# gd_density = 0.0015 # g/cm3
# gd_density = 0.0075 # g/cm3

gd_wt_per = gd_density/(sample_density+gd_density)*100 # wt.%

wt_per_list = [20.3, 4.6, 3.1, 63.4, 2.3, 3.2, gd_wt_per] # weight or wt.%
total_weight = sum(wt_per_list)

# Form dictionary
d = dict(zip(layer_list, wt_per_list))
d
# Out:
# {'Al2O3': 4.6,
#  'CaO': 63.4,
#  'Fe2O3': 3.1,
#  'Gd': 0.0,
#  'MgO': 2.3,
#  'SO3': 3.2,
#  'SiO2': 20.3}

# %%
# Load layer into Resonance()
for each_layer in d.keys():
    o_reso.add_layer(formula=each_layer, thickness=sample_thickness, density=sample_density*d[each_layer]/total_weight)

# %%
pprint.pprint(o_reso.stack)
# Out:
# {'Al2O3': {'Al': {'density': {'units': 'g/cm3', 'value': 2.6989},
#                   'isotopes': {'density': {'units': 'g/cm3',
#                                            'value': [2.6989000440121687]},
#                                'file_names': ['Al-27.csv'],
#                                'isotopic_ratio': [1.0],
#                                'list': ['27-Al'],
#                                'mass': {'units': 'g/mol',
#                                         'value': [26.98153844]}},
#                   'molar_mass': {'units': 'g/mol', 'value': 26.981538}},
#            'O': {'density': {'units': 'g/cm3', 'value': 1.14},
#                  'isotopes': {'density': {'units': 'g/cm3',
#                                           'value': [1.1396804048398064,
#                                                     1.2112335406327737]},
#                               'file_names': ['O-16.csv', 'O-17.csv'],
#                               'isotopic_ratio': [0.9975700000000001,
#                                                  0.00037999999999999997],
#                               'list': ['16-O', '17-O'],
#                               'mass': {'units': 'g/mol',
#                                        'value': [15.9949146221, 16.9991315]}},
#                  'molar_mass': {'units': 'g/mol', 'value': 15.9994}},
#            'atoms_per_cm3': {'Al': 8.411451727533331e+20,
#                              'O': 1.2617177591299994e+21},
#            'density': {'units': 'g/cm3', 'value': 0.07120743034055727},
#            'elements': ['Al', 'O'],
#            'stoichiometric_ratio': [2, 3],
#            'thickness': {'units': 'mm', 'value': 23}},
#  'CaO': {'Ca': {'density': {'units': 'g/cm3', 'value': 1.55},
#                 'isotopes': {'density': {'units': 'g/cm3',
#                                          'value': [1.5455366126054193,
#                                                    1.6227321314686358,
#                                                    1.6614124592045512,
#                                                    1.6999599706821698,
#                                                    1.7772399780428163,
#                                                    1.8545443310544436]},
#                              'file_names': ['Ca-40.csv',
#                                             'Ca-42.csv',
#                                             'Ca-43.csv',
#                                             'Ca-44.csv',
#                                             'Ca-46.csv',
#                                             'Ca-48.csv'],
#                              'isotopic_ratio': [0.96941,
#                                                 0.00647,
#                                                 0.00135,
#                                                 0.02086,
#                                                 4e-05,
#                                                 0.00187],
#                              'list': ['40-Ca',
#                                       '42-Ca',
#                                       '43-Ca',
#                                       '44-Ca',
#                                       '46-Ca',
#                                       '48-Ca'],
#                              'mass': {'units': 'g/mol',
#                                       'value': [39.9625912,
#                                                 41.9586183,
#                                                 42.9587668,
#                                                 43.9554811,
#                                                 45.9536928,
#                                                 47.952534]}},
#                 'molar_mass': {'units': 'g/mol', 'value': 40.078}},
#          'O': {'density': {'units': 'g/cm3', 'value': 1.14},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [1.1396804048398064,
#                                                   1.2112335406327737]},
#                             'file_names': ['O-16.csv', 'O-17.csv'],
#                             'isotopic_ratio': [0.9975700000000001,
#                                                0.00037999999999999997],
#                             'list': ['16-O', '17-O'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [15.9949146221, 16.9991315]}},
#                'molar_mass': {'units': 'g/mol', 'value': 15.9994}},
#          'atoms_per_cm3': {'Ca': 1.0539494454756312e+22,
#                            'O': 1.0539494454756312e+22},
#          'density': {'units': 'g/cm3', 'value': 0.981424148606811},
#          'elements': ['Ca', 'O'],
#          'stoichiometric_ratio': [1, 1],
#          'thickness': {'units': 'mm', 'value': 23}},
#  'Fe2O3': {'Fe': {'density': {'units': 'g/cm3', 'value': 7.874},
#                   'isotopes': {'density': {'units': 'g/cm3',
#                                            'value': [7.6053456340800425,
#                                                      7.886681602567821,
#                                                      8.027743385509893,
#                                                      8.168442128337363]},
#                                'file_names': ['Fe-54.csv',
#                                               'Fe-56.csv',
#                                               'Fe-57.csv',
#                                               'Fe-58.csv'],
#                                'isotopic_ratio': [0.058449999999999995,
#                                                   0.91754,
#                                                   0.02119,
#                                                   0.0028199999999999996],
#                                'list': ['54-Fe', '56-Fe', '57-Fe', '58-Fe'],
#                                'mass': {'units': 'g/mol',
#                                         'value': [53.9396148,
#                                                   55.9349421,
#                                                   56.9353987,
#                                                   57.9332805]}},
#                   'molar_mass': {'units': 'g/mol', 'value': 55.845}},
#            'O': {'density': {'units': 'g/cm3', 'value': 1.14},
#                  'isotopes': {'density': {'units': 'g/cm3',
#                                           'value': [1.1396804048398064,
#                                                     1.2112335406327737]},
#                               'file_names': ['O-16.csv', 'O-17.csv'],
#                               'isotopic_ratio': [0.9975700000000001,
#                                                  0.00037999999999999997],
#                               'list': ['16-O', '17-O'],
#                               'mass': {'units': 'g/mol',
#                                        'value': [15.9949146221, 16.9991315]}},
#                  'molar_mass': {'units': 'g/mol', 'value': 15.9994}},
#            'atoms_per_cm3': {'Fe': 3.6194056109374105e+20,
#                              'O': 5.4291084164061155e+20},
#            'density': {'units': 'g/cm3', 'value': 0.047987616099071206},
#            'elements': ['Fe', 'O'],
#            'stoichiometric_ratio': [2, 3],
#            'thickness': {'units': 'mm', 'value': 23}},
#  'Gd': {'Gd': {'density': {'units': 'g/cm3', 'value': 7.901},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [7.633184387841018,
#                                                   7.6835276002925275,
#                                                   7.733728016928458,
#                                                   7.784061130168521,
#                                                   7.834280891065183,
#                                                   7.884618023891892,
#                                                   7.934870092216217,
#                                                   8.035507980610491]},
#                             'file_names': ['Gd-152.csv',
#                                            'Gd-153.csv',
#                                            'Gd-154.csv',
#                                            'Gd-155.csv',
#                                            'Gd-156.csv',
#                                            'Gd-157.csv',
#                                            'Gd-158.csv',
#                                            'Gd-160.csv'],
#                             'isotopic_ratio': [0.002,
#                                                0.0,
#                                                0.0218,
#                                                0.14800000000000002,
#                                                0.2047,
#                                                0.1565,
#                                                0.2484,
#                                                0.2186],
#                             'list': ['152-Gd',
#                                      '153-Gd',
#                                      '154-Gd',
#                                      '155-Gd',
#                                      '156-Gd',
#                                      '157-Gd',
#                                      '158-Gd',
#                                      '160-Gd'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [151.919788,
#                                                152.921746,
#                                                153.920862,
#                                                154.922619,
#                                                155.92212,
#                                                156.923957,
#                                                157.924101,
#                                                159.927051]}},
#                'molar_mass': {'units': 'g/mol', 'value': 157.25}},
#         'atoms_per_cm3': {'Gd': 0.0},
#         'density': {'units': 'g/cm3', 'value': 0.0},
#         'elements': ['Gd'],
#         'stoichiometric_ratio': [1],
#         'thickness': {'units': 'mm', 'value': 23}},
#  'MgO': {'Mg': {'density': {'units': 'g/cm3', 'value': 1.738},
#                 'isotopes': {'density': {'units': 'g/cm3',
#                                          'value': [1.715120461723925,
#                                                    1.7866852392824524,
#                                                    1.857961189200576]},
#                              'file_names': ['Mg-24.csv',
#                                             'Mg-25.csv',
#                                             'Mg-26.csv'],
#                              'isotopic_ratio': [0.7898999999999999,
#                                                 0.1,
#                                                 0.1101],
#                              'list': ['24-Mg', '25-Mg', '26-Mg'],
#                              'mass': {'units': 'g/mol',
#                                       'value': [23.9850419,
#                                                 24.98583702,
#                                                 25.98259304]}},
#                 'molar_mass': {'units': 'g/mol', 'value': 24.305}},
#          'O': {'density': {'units': 'g/cm3', 'value': 1.14},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [1.1396804048398064,
#                                                   1.2112335406327737]},
#                             'file_names': ['O-16.csv', 'O-17.csv'],
#                             'isotopic_ratio': [0.9975700000000001,
#                                                0.00037999999999999997],
#                             'list': ['16-O', '17-O'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [15.9949146221, 16.9991315]}},
#                'molar_mass': {'units': 'g/mol', 'value': 15.9994}},
#          'atoms_per_cm3': {'Mg': 5.3197811600700087e+20,
#                            'O': 5.3197811600700087e+20},
#          'density': {'units': 'g/cm3', 'value': 0.03560371517027863},
#          'elements': ['Mg', 'O'],
#          'stoichiometric_ratio': [1, 1],
#          'thickness': {'units': 'mm', 'value': 23}},
#  'SO3': {'O': {'density': {'units': 'g/cm3', 'value': 1.14},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [1.1396804048398064,
#                                                   1.2112335406327737]},
#                             'file_names': ['O-16.csv', 'O-17.csv'],
#                             'isotopic_ratio': [0.9975700000000001,
#                                                0.00037999999999999997],
#                             'list': ['16-O', '17-O'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [15.9949146221, 16.9991315]}},
#                'molar_mass': {'units': 'g/mol', 'value': 15.9994}},
#          'S': {'density': {'units': 'g/cm3', 'value': 2.07},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [2.0640008210915326,
#                                                   2.1285176702011537,
#                                                   2.1928421748978635,
#                                                   2.321904176566349]},
#                             'file_names': ['S-32.csv',
#                                            'S-33.csv',
#                                            'S-34.csv',
#                                            'S-36.csv'],
#                             'isotopic_ratio': [0.9493, 0.0076, 0.0429, 0.0002],
#                             'list': ['32-S', '33-S', '34-S', '36-S'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [31.97207069,
#                                                32.9714585,
#                                                33.96786683,
#                                                35.96708088]}},
#                'molar_mass': {'units': 'g/mol', 'value': 32.065}},
#          'atoms_per_cm3': {'O': 1.1177808893822178e+21,
#                            'S': 3.7259362979407266e+20},
#          'density': {'units': 'g/cm3', 'value': 0.04953560371517028},
#          'elements': ['S', 'O'],
#          'stoichiometric_ratio': [1, 3],
#          'thickness': {'units': 'mm', 'value': 23}},
#  'SiO2': {'O': {'density': {'units': 'g/cm3', 'value': 1.14},
#                 'isotopes': {'density': {'units': 'g/cm3',
#                                          'value': [1.1396804048398064,
#                                                    1.2112335406327737]},
#                              'file_names': ['O-16.csv', 'O-17.csv'],
#                              'isotopic_ratio': [0.9975700000000001,
#                                                 0.00037999999999999997],
#                              'list': ['16-O', '17-O'],
#                              'mass': {'units': 'g/mol',
#                                       'value': [15.9949146221, 16.9991315]}},
#                 'molar_mass': {'units': 'g/mol', 'value': 15.9994}},
#           'Si': {'density': {'units': 'g/cm3', 'value': 2.33},
#                  'isotopes': {'density': {'units': 'g/cm3',
#                                           'value': [2.320992641084937,
#                                                     2.4039177759911703,
#                                                     2.4866527073614497]},
#                               'file_names': ['Si-28.csv',
#                                              'Si-29.csv',
#                                              'Si-30.csv'],
#                               'isotopic_ratio': [0.9222969999999999,
#                                                  0.046832000000000006,
#                                                  0.030872],
#                               'list': ['28-Si', '29-Si', '30-Si'],
#                               'mass': {'units': 'g/mol',
#                                        'value': [27.9769265327,
#                                                  28.97649472,
#                                                  29.97377022]}},
#                  'molar_mass': {'units': 'g/mol', 'value': 28.0855}},
#           'atoms_per_cm3': {'O': 6.299171305033663e+21,
#                             'Si': 3.1495856525168314e+21},
#           'density': {'units': 'g/cm3', 'value': 0.3142414860681115},
#           'elements': ['Si', 'O'],
#           'stoichiometric_ratio': [1, 2],
#           'thickness': {'units': 'mm', 'value': 23}}}

# %%
o_reso.plot(x_axis='lambda', y_axis='transmission', all_layers=True, lambda_max_angstroms=20)

# %%
# interpolate with the beam shape energy
energy = o_reso.total_signal['energy_eV']
trans = o_reso.total_signal['transmission']

y_function = interp1d(x=energy, y=trans, kind='cubic')
df['transmission'] = y_function(df['energy_eV'])
df['trans_flux'] = df['transmission'] * df['flux']
df
# Out:
#     wavelength_A  energy_eV          flux  transmission    trans_flux
# 0       0.812655   0.123843  1.776169e+04      0.746302  1.325558e+04
# 1       1.028404   0.077332  1.201199e+05      0.744319  8.940753e+04
# 2       1.244153   0.052837  2.919421e+05      0.742187  2.166755e+05
# 3       1.459902   0.038374  5.860009e+05      0.739915  4.335907e+05
# 4       1.675651   0.029128  1.030660e+06      0.737493  7.601044e+05
# 5       1.891400   0.022862  1.509066e+06      0.734939  1.109072e+06
# 6       2.107149   0.018420  1.863847e+06      0.732237  1.364779e+06
# 7       2.322899   0.015157  1.989239e+06      0.729388  1.450927e+06
# 8       2.538648   0.012691  2.231573e+06      0.726416  1.621050e+06
# 9       2.754397   0.010780  2.254231e+06      0.723303  1.630493e+06
# 10      2.970146   0.009271  2.117908e+06      0.720074  1.525050e+06
# 11      3.185895   0.008058  1.921868e+06      0.716683  1.377370e+06
# 12      3.401644   0.007068  1.725260e+06      0.713191  1.230440e+06
# 13      3.617393   0.006250  1.556134e+06      0.709564  1.104176e+06
# 14      3.833142   0.005566  1.394662e+06      0.705827  9.843898e+05
# 15      4.048891   0.004989  1.156793e+06      0.701964  8.120276e+05
# 16      4.264640   0.004497  1.126788e+06      0.697986  7.864818e+05
# 17      4.480389   0.004074  1.016330e+06      0.693911  7.052425e+05
# 18      4.696139   0.003709  8.334823e+05      0.689761  5.749038e+05
# 19      4.911888   0.003390  7.745360e+05      0.685491  5.309371e+05
# 20      5.127637   0.003111  7.204620e+05      0.681100  4.907065e+05
# 21      5.343386   0.002865  6.151784e+05      0.676672  4.162742e+05
# 22      5.559135   0.002646  5.240242e+05      0.672279  3.522906e+05
# 23      5.774884   0.002452  4.438901e+05      0.667834  2.964447e+05
# 24      5.990633   0.002279  3.748091e+05      0.663195  2.485713e+05
# 25      6.206382   0.002123  3.170087e+05      0.658321  2.086935e+05
# 26      6.422131   0.001983  2.684945e+05      0.653263  1.753975e+05
# 27      6.637880   0.001856  2.252935e+05      0.648192  1.460333e+05
# 28      6.853629   0.001741  1.899357e+05      0.643242  1.221746e+05
# 29      7.069379   0.001637  1.652598e+05      0.638494  1.055173e+05
# ..           ...        ...           ...           ...           ...
# 44     10.305615   0.000770  9.856068e+03      0.561838  5.537513e+03
# 45     10.521364   0.000739  7.545377e+03      0.555822  4.193883e+03
# 46     10.737113   0.000709  6.609386e+03      0.549825  3.634007e+03
# 47     10.952862   0.000682  4.710191e+03      0.543868  2.561722e+03
# 48     11.168611   0.000656  3.710300e+03      0.537967  1.996018e+03
# 49     11.384360   0.000631  2.448360e+03      0.532136  1.302859e+03
# 50     11.600109   0.000608  2.126788e+03      0.526386  1.119511e+03
# 51     11.815859   0.000586  1.062280e+03      0.520727  5.531582e+02
# 52     12.031608   0.000565  1.862909e+03      0.515168  9.597113e+02
# 53     12.247357   0.000545  2.771285e+03      0.509714  1.412564e+03
# 54     12.463106   0.000527  1.904687e+03      0.504371  9.606687e+02
# 55     12.678855   0.000509  2.842666e+03      0.499141  1.418892e+03
# 56     12.894604   0.000492  1.178463e+03      0.494028  5.821940e+02
# 57     13.110353   0.000476  7.392747e+02      0.489033  3.615301e+02
# 58     13.326102   0.000461  7.855888e+02      0.484158  3.803489e+02
# 59     13.541851   0.000446  1.787310e+02      0.479401  8.568389e+01
# 60     13.973349   0.000419  5.113648e+02      0.470245  2.404667e+02
# 61     14.189099   0.000406  8.848219e+02      0.465843  4.121880e+02
# 62     14.404848   0.000394  8.028571e+02      0.461556  3.705638e+02
# 63     14.620597   0.000383  1.078275e+03      0.457384  4.931852e+02
# 64     14.836346   0.000372  1.106127e+02      0.453323  5.014323e+01
# 65     15.052095   0.000361  1.260109e+03      0.449371  5.662568e+02
# 66     15.267844   0.000351  8.664395e+02      0.445527  3.860223e+02
# 67     15.483593   0.000341  1.239260e+03      0.441788  5.474900e+02
# 68     15.699342   0.000332  1.170664e+03      0.438151  5.129277e+02
# 69     15.915091   0.000323  8.130430e+02      0.434614  3.533599e+02
# 70     16.130840   0.000314  1.207986e+02      0.431174  5.208525e+01
# 71     16.346589   0.000306  2.553641e+02      0.427829  1.092522e+02
# 72     16.562339   0.000298  3.654197e+02      0.424576  1.551486e+02
# 73     16.778088   0.000291  5.451853e+02      0.421413  2.297482e+02
#
# [74 rows x 5 columns]

# %%
total_trans = sum(df['trans_flux'])/sum(df['flux'])*100
print("Total neutron transmission (CG-1D): {} %".format(total_trans))
# Out:
# Total neutron transmission (CG-1D): 70.84057549588468 %

# %%
plt.plot(df['wavelength_A'], df['transmission'])
plt.ylim(top=1, bottom=0)
plt.xlim(left=0, right=20)
plt.show()
