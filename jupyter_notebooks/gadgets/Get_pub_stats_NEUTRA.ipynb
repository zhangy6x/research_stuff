# %%
import numpy as np
import pandas as pd
import os
from pprint import pprint

# %%
file_path = '/Users/y9z/OneDrive - Oak Ridge National Laboratory/CG1D/SuiteReview/2020_review_documents/stats/raw_files/NEUTRA.csv'

# %%
# ris_keys = ['type_of_reference', 'authors', 'title', 'journal_name', 'volume', 'number', 'issn', 'place_published', 'publisher', 'note', 'start_page', 'year', 'abstract', 'label', 'doi', 'url']

# %%
df = pd.read_csv(file_path)
df
# Out:
#            PID   Publication Type    Full Text  \
# 0    psi:11490    Journal Article   Restricted
# 1    psi:11489    Journal Article   Restricted
# 2    psi:11491    Journal Article   Restricted
# 3    psi:31000  Proceedings Paper   Restricted
# 4    psi:13222    Journal Article   Restricted
# ..         ...                ...          ...
# 283  psi:27237    Journal Article  Open Access
# 284  psi:31564    Journal Article   Restricted
# 285  psi:28898  Proceedings Paper  Open Access
# 286  psi:31983    Journal Article   Restricted
# 287  psi:32838    Journal Article   Restricted
#
#                                              Author(s)  \
# 0    Kardjilov, N.; Lehmann, E.; Steichele, E.; Von...
# 1    Deschler-Erb, E.; Lehmann, E.H.; Pernet, L.; V...
# 2    Goers, D.; Holzapfel, M.; Scheifele, W.; Lehma...
# 3    Kardjilov, N.; Lee, S.W.; Lehmann, E.; Lim, I....
# 4    Tamaki, Masayoshi; Iida, Kazuhiro; Mori, Noria...
# ..                                                 ...
# ...

# %%
df.to_clipboard()

# %%
df_stat = df['Publication Year'].value_counts()

# %%
df_stat.sort_index(inplace=True)

# %%
df_stat.to_clipboard()

# %%
df['Publication Type'].value_counts().to_clipboard()

# %%
df['Beamline'].value_counts().to_clipboard()
