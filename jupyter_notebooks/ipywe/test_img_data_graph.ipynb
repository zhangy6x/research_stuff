# %%
import ipywe.imgdatagraph

# %%
import numpy as np

xg,yg = np.mgrid[1:500, 1:500]

class Image:
    def __init__(self, x0, y0, sigma):
        self.data = np.exp(-((xg-x0)**2+(yg-y0)**2)/2/sigma**2)

image = Image(250., 250., 23)

# %%
is1 = ipywe.imgdatagraph.ImageDataGraph(image, 300, 300)
is1
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     456                 for i,k in enumerate(data.get('buffer_keys', [])):
#     457                     sync_data[k] = msg['buffers'][i]
# --> 458                 self.set_state(sync_data) # handles all methods
#     459
#     460         # Handle a state request.
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     335                     from_json = self.trait_metadata(name, 'from_json',
#     336                                                     self._trait_from_json)
# --> 337                     self.set_trait(name, from_json(sync_data[name], self))
#     338
#     339     def send(self, content, buffers=None):
#
# ~/anaconda/envs/py36/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87         if type is None:
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#      91                 return
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     396                 # Send new state to front-end
#     397                 self.send_state(key=name)
# --> 398         LoggingConfigurable.notify_change(self, change)
#     399
#     400     #-------------------------------------------------------------------------
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywe/imgdatagraph.py in graph_data(self, change)
#     102             self._graphb64 = self.nowidth_graph()
#     103         else:
# --> 104             self._graphb64 = self.width_graph()
#     105         return
#     106
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywe/imgdatagraph.py in width_graph(self)
#     205             dists, vals, bar_width = self.get_data_vertical(p1x_abs, p1y_abs, p2y_abs)
#     206         else:
# --> 207             dists, vals, bar_width = self.get_data_diagonal(p1x_abs, p1y_abs, p2x_abs, p2y_abs)
#     208         plt.bar(dists, vals, width=bar_width)
#     209         plt.xlabel("Distance from Initial Point")
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywe/imgdatagraph.py in get_data_diagonal(self, x_init, y_init, x_fin, y_fin)
#     352             x0 = tempx
#     353             y0 = tempy
# --> 354         slope = (y1 - y0) / (x1 - x0)
#     355         angle = np.arctan(slope)
#     356         wid_x = abs((self._linepix_width * np.cos(angle))/self.width * self._ncols)
#
# ZeroDivisionError: float division by zero
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     456                 for i,k in enumerate(data.get('buffer_keys', [])):
#     457                     sync_data[k] = msg['buffers'][i]
# --> 458                 self.set_state(sync_data) # handles all methods
#     459
#     460         # Handle a state request.
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     335                     from_json = self.trait_metadata(name, 'from_json',
#     336                                                     self._trait_from_json)
# --> 337                     self.set_trait(name, from_json(sync_data[name], self))
#     338
#     339     def send(self, content, buffers=None):
#
# ~/anaconda/envs/py36/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87         if type is None:
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#      91                 return
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     396                 # Send new state to front-end
#     397                 self.send_state(key=name)
# --> 398         LoggingConfigurable.notify_change(self, change)
#     399
#     400     #-------------------------------------------------------------------------
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywe/imgdatagraph.py in graph_data(self, change)
#     102             self._graphb64 = self.nowidth_graph()
#     103         else:
# --> 104             self._graphb64 = self.width_graph()
#     105         return
#     106
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywe/imgdatagraph.py in width_graph(self)
#     205             dists, vals, bar_width = self.get_data_vertical(p1x_abs, p1y_abs, p2y_abs)
#     206         else:
# --> 207             dists, vals, bar_width = self.get_data_diagonal(p1x_abs, p1y_abs, p2x_abs, p2y_abs)
#     208         plt.bar(dists, vals, width=bar_width)
#     209         plt.xlabel("Distance from Initial Point")
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywe/imgdatagraph.py in get_data_diagonal(self, x_init, y_init, x_fin, y_fin)
#     352             x0 = tempx
#     353             y0 = tempy
# --> 354         slope = (y1 - y0) / (x1 - x0)
#     355         angle = np.arctan(slope)
#     356         wid_x = abs((self._linepix_width * np.cos(angle))/self.width * self._ncols)
#
# ZeroDivisionError: float division by zero
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     456                 for i,k in enumerate(data.get('buffer_keys', [])):
#     457                     sync_data[k] = msg['buffers'][i]
# --> 458                 self.set_state(sync_data) # handles all methods
#     459
#     460         # Handle a state request.
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     335                     from_json = self.trait_metadata(name, 'from_json',
#     336                                                     self._trait_from_json)
# --> 337                     self.set_trait(name, from_json(sync_data[name], self))
#     338
#     339     def send(self, content, buffers=None):
#
# ~/anaconda/envs/py36/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87         if type is None:
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#      91                 return
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     396                 # Send new state to front-end
#     397                 self.send_state(key=name)
# --> 398         LoggingConfigurable.notify_change(self, change)
#     399
#     400     #-------------------------------------------------------------------------
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywe/imgdatagraph.py in graph_data(self, change)
#     102             self._graphb64 = self.nowidth_graph()
#     103         else:
# --> 104             self._graphb64 = self.width_graph()
#     105         return
#     106
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywe/imgdatagraph.py in width_graph(self)
#     205             dists, vals, bar_width = self.get_data_vertical(p1x_abs, p1y_abs, p2y_abs)
#     206         else:
# --> 207             dists, vals, bar_width = self.get_data_diagonal(p1x_abs, p1y_abs, p2x_abs, p2y_abs)
#     208         plt.bar(dists, vals, width=bar_width)
#     209         plt.xlabel("Distance from Initial Point")
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ipywe/imgdatagraph.py in get_data_diagonal(self, x_init, y_init, x_fin, y_fin)
#     352             x0 = tempx
#     353             y0 = tempy
# --> 354         slope = (y1 - y0) / (x1 - x0)
#     355         angle = np.arctan(slope)
#     356         wid_x = abs((self._linepix_width * np.cos(angle))/self.width * self._ncols)
#
# ZeroDivisionError: float division by zero
