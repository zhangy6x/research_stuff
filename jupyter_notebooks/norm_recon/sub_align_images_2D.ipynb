# %%
import os
import utilities as rocku
import matplotlib.pyplot as plt
import numpy as np
import multiprocessing as mp
import timeit
from pystackreg import StackReg
from PIL import Image
import dxchange
from tqdm import tqdm
# from skimage.transform import rescale
import skimage as ski
ncore = mp.cpu_count()
print("CPU cores:", ncore)
# Out:
# CPU cores: 256

# %%
# need to change
ipts="30610"
# scan_type = 'ct_scans'
# scan_type = 'radiographs'
scan_type = 'processed_data/normalized'
# scan_type = 'analysis'
# scan_type = 'analysis'
####################################
##################################
scan_loc = "/HFIR/CG1D/IPTS-"+ipts+"/shared/" + scan_type
save_loc = "/HFIR/CG1D/IPTS-"+ipts+"/shared/analysis/"
folder_list = os.listdir(scan_loc)
folder_list.sort()
folder_list
# Out:
# ['2023_08_01_dehydration',
#  '2023_08_01_hydration',
#  '2023_08_03_calibration',
#  '2023_08_03_dehydration2',
#  '2023_08_03_hydration',
#  '2023_08_03_throughflow',
#  '2023_08_03_throughflow_td_b_h',
#  '2023_08_07',
#  '2023_08_07_calibration']

# %%
sample_name = "2023_08_03_throughflow_td_b_h"
######################
######################
######################
scan_dir = os.path.join(scan_loc, sample_name)
fname_list = os.listdir(scan_dir)
fname_list.sort()
fname_list
# Out:
# ['20230807_hydrated_straight_0030_0028.tiff',
#  '20230807_hydrated_straight_0030_0029.tiff',
#  '20230807_hydrated_straight_0030_0030.tiff',
#  '20230807_hydrated_straight_0030_0031.tiff',
#  '20230807_hydrated_straight_0030_0032.tiff']

# %%
to_rmv = [
# '01_heat_hold_at_400_0030_0001.tiff',
#  '01_heat_hold_at_400_0030_0006.tiff',
#  '01_heat_hold_at_400_0030_0011.tiff',
#  '02_heating_at_800_0030_0001.tiff',
#  '02_heating_at_800_0030_0006.tiff',
#  '02_heating_at_800_0030_0011.tiff',
#  '02_heating_at_800_0030_0016.tiff',
]
fname_list = rocku.remove_fnames(fname_list, to_rmv)
fname_list
# Out:
# 158
# 158
# ['20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5495.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5496.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5497.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5498.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5499.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5500.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5501.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5502.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5503.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5504.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5505.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5506.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5507.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd2_0030_5508.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5351.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5352.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5353.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5354.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5355.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5356.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5357.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5358.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5359.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5360.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5361.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5362.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5363.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5364.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5365.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5366.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5367.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5368.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5369.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5370.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5371.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5372.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5373.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5374.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5375.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5376.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5377.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5378.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5379.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5380.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5381.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5382.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5383.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5384.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5385.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5386.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5387.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5388.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5389.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5390.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5391.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5392.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5393.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5394.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5395.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5396.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5397.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5398.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5399.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5400.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5401.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5402.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5403.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5404.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5405.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5406.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5407.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5408.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5409.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5410.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5411.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5412.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5413.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5414.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5415.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5416.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5417.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5418.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5419.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5420.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5421.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5422.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5423.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5424.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5425.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5426.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5427.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5428.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5429.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5430.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5431.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5432.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5433.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5434.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5435.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5436.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5437.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5438.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5439.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5440.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5441.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5442.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5443.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5444.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5445.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5446.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5447.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5448.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5449.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5450.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5451.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5452.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5453.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5454.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5455.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5456.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5457.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5458.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5459.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5460.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5461.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5462.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5463.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5464.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5465.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5466.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5467.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5468.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5469.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5470.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5471.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5472.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5473.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5474.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5475.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5476.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5477.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5478.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5479.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5480.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5481.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5482.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5483.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5484.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5485.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5486.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5487.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5488.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5489.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5490.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5491.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5492.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5493.tiff',
#  '20230804_throughflowreactor_bot_hyd_top_dhyd_0030_5494.tiff']

# %%
img_stack = rocku.read_img_stack(scan_dir, fname_list, flipud=False)
trans_algo_dict = {
    'TRANSLATION': StackReg.TRANSLATION,
    'RIGID_BODY': StackReg.RIGID_BODY,
    'SCALED_ROTATION': StackReg.SCALED_ROTATION,
    'AFFINE': StackReg.AFFINE,
    'BILINEAR': StackReg.BILINEAR
}
# Out:
# 158it [00:00, 248.50it/s]

# %%
f, ax = plt.subplots(1, 3, figsize=(20, 20))
ax[0].imshow(img_stack[0], cmap='gray')#vmin=0, vmax=1,
ax[0].set_title('first image')

ax[1].imshow(img_stack[-1], cmap='gray')
ax[1].set_title('last image')

ax[2].imshow(np.divide(img_stack[-1], img_stack[0]), vmin=0.8, vmax=1.2)
ax[2].set_title('last/first')
# Out:
# Text(0.5, 1.0, 'last/first')

# %%
# roi = True
roi = False
roi_left = 0
roi_right = -1
roi_top = 0
roi_bottom = 900
# roi_left = 250
# roi_right = 1350
# roi_top = 900
# roi_bottom = 1350
#########################
#########################
img_stack_roi = rocku.crop(img_stack, roi_left, roi_right, roi_top, roi_bottom, roi)
f, ax = plt.subplots(1, 4, figsize=(20, 10))
ax[0].imshow(img_stack_roi[0], cmap='gray')# vmin=0, vmax=1)
ax[0].set_title('first image')

ax[1].imshow(img_stack_roi[-1], cmap='gray')# vmin=0, vmax=1)
ax[1].set_title('last image')

ax[2].imshow(np.divide(img_stack_roi[-1], img_stack_roi[0]), vmin=0.8, vmax=1.2)
ax[2].set_title('last/first')

ax[3].imshow(rocku.composite_images([img_stack_roi[0], img_stack_roi[-1]]))
ax[3].set_title('overlay (reference=green, changed=red)')
# ax[3].axis('off');
# Out:
# Text(0.5, 1.0, 'overlay (reference=green, changed=red)')

# %%
pixel_bin_size = 1
# pixel_bin_size = 2
func = np.sum
# dtype = np.float16
dtype = np.float32
# dtype = np.float64
#################################################
t0 = timeit.default_timer()
img_stack_resized = rocku.bin_pix(img_stack_roi, pixel_bin_size=pixel_bin_size, func=func, dtype=dtype)
t1 = timeit.default_timer()
print("Time: {} s".format(t1-t0))
# Out:
# Pixel_bin_size = 1, no binning
# Time: 6.316000144579448e-05 s

# %%
perform_reg = False
# perform_reg = True
trans_algo = 'RIGID_BODY'
# trans_algo = 'TRANSLATION'
# trans_algo = "SCALED_ROTATION"
#########################
#load reference and "moved" image
random_idx = None
if perform_reg:
    ref = img_stack_resized[0]
    mov = img_stack_resized[-1]
    sr = StackReg(trans_algo_dict[trans_algo])
    reg = sr.register_transform(ref, mov)
    reg = reg.clip(min=0)
    after_reg = rocku.composite_images([ref, reg])
    before_reg = rocku.composite_images([ref, mov])
    
    f, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(np.divide(mov, ref), vmin=0.8, vmax=1.2)
    ax[0].set_title('last/first (unregistered)')
    
    ax[1].imshow(np.divide(reg, ref), vmin=0.8, vmax=1.2)
    ax[1].set_title('last/first (registered)')
    
    ax[2].imshow(before_reg)
    ax[2].set_title('overlay (reference=green, changed=red)')
    
    ax[3].imshow(after_reg)
    ax[3].set_title('overlay (reference=green, changed=red)')

# %%
reference = 'previous'
# reference = 'first'
# reference = 'mean'
moving_avg = 1
n_frames = 1
init_avg_size = 5
#################################################
if perform_reg:
    sr = StackReg(trans_algo_dict[trans_algo])
    reg_stack_roi = sr.register_transform_stack(img_stack_resized, reference=reference, n_frames=n_frames, moving_average=moving_avg, verbose=True)#, progress_callback=rocku.show_progress)
else:
    reg_stack_roi = img_stack_resized[:]
if init_avg_size > 1:
    reg_ratio = np.divide(reg_stack_roi, np.mean(reg_stack_roi[0:init_avg_size-1,:,:], axis=0))
else:
    reg_ratio = np.divide(reg_stack_roi, reg_stack_roi[0])
if random_idx is None:
    num_of_row = 2
    fig_per_row = 4
    random_idx = rocku.generate_randint_list(num_of_ele=fig_per_row*num_of_row, range_min=0, range_max=len(reg_ratio))
fig_size = (20,10)
vmin=0.8
vmax=1.2
rocku.plot_imgs_from_stack(reg_ratio, random_idx, vmin=vmin, vmax=vmax, fig_per_row=fig_per_row, figsize=fig_size)

# %% [markdown]
# # reference = 'previous'
# reference = 'first'
# ###############################################
# reg_dict = {}
# sr = StackReg(trans_algo_dict[trans_algo])
# print("Registration using '{}'".format(ref_name))
# tmats = sr.register_stack(unreg_dict[ref_name], reference=reference, progress_callback=rocku.show_progress)
# for ee in unreg_dict.keys():
#     print("Apply transform to {}".format(ee))
#     reg_dict[ee] = sr.transform_stack(unreg_dict[ee], tmats=tmats)

# %% [markdown]
# # Crop

# %%
###################### need to change start
crop = False
# crop_left = 250
# crop_right = 1650
# crop_top = 750
# crop_bottom = 1950
crop_left = 450
crop_right = 1200
crop_top = 1750#530
crop_bottom = 2190
###################### need to change end
reg_ratio_out = rocku.crop(reg_ratio, crop_left, crop_right, crop_top, crop_bottom, crop)
if crop:
    print("Cropped:")
    plt.imshow(reg_ratio_out[-1])
    plt.colorbar()
    plt.show()

# %% [markdown]
# # Save files

# %%
# name_str = 'RT'
name_str = None
############################################################
dir_name_list = [sample_name, name_str, trans_algo, reference]
if name_str is None:
    dir_name_list.remove(name_str)
if not perform_reg:
    dir_name_list.remove(trans_algo)
    dir_name_list.remove(reference)

save_to = save_loc + "_".join(dir_name_list)
save_to_norm = save_to + '/normalized'
if perform_reg:
    save_to_ratio = save_to + '/ratio'
else:
    save_to_ratio = save_to + '_ratio'

if crop:
    reg_stack_subdir = save_to_norm + "/full"
    reg_ratio_subdir = save_to_ratio + "/full"
    reg_stack_crop_subdir = save_to_norm + "/crop"
    reg_ratio_crop_subdir = save_to_ratio + "/crop"
else:
    reg_stack_subdir = save_to_norm
    reg_ratio_subdir = save_to_ratio

reg_stack_out = reg_stack_roi
reg_stack_crop_out = rocku.crop(reg_stack_roi, crop_left, crop_right, crop_top, crop_bottom, crop)
###############################
###############################
if perform_reg:
    if not os.path.exists(save_to):
        os.mkdir(save_to)
    if not os.path.exists(save_to_norm):
        os.mkdir(save_to_norm)
    if not os.path.exists(reg_stack_subdir):
        os.mkdir(reg_stack_subdir)
    print("Saving to '{}' ...".format(reg_stack_subdir))
if not os.path.exists(save_to_ratio):
    os.mkdir(save_to_ratio)
if not os.path.exists(reg_ratio_subdir):
    os.mkdir(reg_ratio_subdir)
print("Saving to '{}' ...".format(reg_ratio_subdir))
for i, e_name in tqdm(enumerate(fname_list)):
    if perform_reg:
        img_pl = Image.fromarray(reg_stack_out[i])
        img_pl.save(reg_stack_subdir + "/" + e_name)
    img_pl_ratio = Image.fromarray(reg_ratio[i])
    img_pl_ratio.save(reg_ratio_subdir + "/" + e_name)
    if crop:
        if perform_reg:
            if not os.path.exists(reg_stack_crop_subdir):
                os.mkdir(reg_stack_crop_subdir)
                img_pl_crop = Image.fromarray(reg_stack_crop_out[i])
                img_pl_crop.save(reg_stack_crop_subdir + "/" + e_name)
        if not os.path.exists(reg_ratio_crop_subdir):
            os.mkdir(reg_ratio_crop_subdir)
        img_pl_ratio_crop = Image.fromarray(reg_ratio_out[i])
        img_pl_ratio_crop.save(reg_ratio_crop_subdir + "/" + e_name)
# Out:
# Saving to '/HFIR/CG1D/IPTS-30610/shared/analysis/2023_08_03_throughflow_td_b_h_ratio' ...
# 158it [00:04, 33.07it/s]
