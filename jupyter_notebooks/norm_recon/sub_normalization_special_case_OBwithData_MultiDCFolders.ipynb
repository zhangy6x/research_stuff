# %%
import os
import shutil
import utilities as rocku
import matplotlib.pyplot as plt
import tomopy
import numpy as np
import pandas as pd
import pprint
import dxchange
from pystackreg import StackReg
import multiprocessing as mp
import timeit
from tqdm import tqdm
ncore = mp.cpu_count()
print("CPU cores:", ncore)
# Out:
# CPU cores: 64

# %%
# need to change
ipts="23768"
# scan_type = 'ct_scans'
scan_type = 'radiographs'
# scan_type = 'alignment_calibration'

# %%
scan_loc = "/HFIR/CG1D/IPTS-"+ipts+"/raw/" + scan_type
sorted(os.listdir(scan_loc))
# Out:
# ['06_29_21_OB',
#  '06_29_21_dark_field',
#  '2021_02_25',
#  '2021_03_25',
#  '2021_04_12',
#  '2021_04_14',
#  '2021_04_15',
#  '2021_04_18_resolution',
#  '2021_04_22_25um_scint',
#  '2021_04_22_BN_PLA',
#  '2021_04_27_light',
#  '2021_05_25',
#  '2021_07_07_Cu_fastCT',
#  '2021_07_07_Cu_fastCT01',
#  '2021_07_26',
#  '2021_07_26_super_res',
#  '2021_09_04_mono_test',
#  '2022_01_04_flux',
#  '2022_01_04_stability',
#  '2022_01_09_stability',
#  '2022_01_13_neutron_eater',
#  '2022_01_23_recover_from_slits',
#  '2022_09_29_startup',
#  '2022_11_08_intensity_check',
#  '2023_05_23_QHYS',
#  '2023_05_23_QHYS_Choppers',
#  '2023_05_23_QHYS_gain_tuning',
#  '2023_05_24_VENUS_chopper',
#  '2023_08_29_beamsize',
#  '2023_08_29_cycle503',
#  '2024_01_22_QHY_resolution',
#  '2024_03_15_QHYL_1X_test_resolution',
#  '2024_03_15_idealVac_plate',
#  '2024_04_09_cycle_506',
#  '2024_04_09_cycle_506_',
#  '2024_04_09_cycle_506_8mm',
#  '2024_06_10_comm_test',
#  '2024_06_11_comm_test',
#  '2024_06_20_BM_calibration',
#  '2024_06_20_QHY_resolution',
#  '2024_06_24_QHYL_resolution',
#  '2024_06_28_O_ring',
#  '2024_07_23_optics_scan_3mmAperture_vert_all_10s',
#  '2024_07_23_optics_scan_pinhole_vert60mm_10s',
#  '2024_07_23_optics_scan_withDiffuser_60mmVertTrans_pinhole_10s',
#  '2024_07_23_optics_scan_woDiffuser_11mmPinhole_VertTrans_10s',
#  '2024_07_23_optics_scan_woDiffuser_16mmPinhole_VertTrans_5s',
#  '2024_07_23_optics_scan_woDiffuser_3mmPinhole_VertTrans_10s',
#  '2024_07_23_optics_scan_woDiffuser_60mmVertTrans_pinhole_10s',
#  '2024_07_23_optics_scan_woDiffuser_60mmVertTrans_pinhole_30s_redo',
#  '2024_07_23_optics_scan_woDiffuser_60mmVertTrans_pinhole_60s',
#  '2024_07_23_optics_scan_woDiffuser_85mmVertTrans_pinhole_10s',
#  '2024_07_23_test_QHYL',
#  '2024_08_07_flux',
#  '2024_10_15',
#  '2024_10_15_imaging_metrics_resolution_QHYL',
#  '2024_10_18_imaging_metrics_resolution_QHYL',
#  'Aug19_2020',
#  'DF_with_light_leak',
#  'Dec17_2019',
#  'Jan03_2020',
#  'Jan30_2020',
#  'Jan31_2020',
#  'July02_2020',
#  'June18_2020',
#  'June19_2020',
#  'June23_2020',
#  'June_15_2020',
#  'MattTest',
#  'Nov11_2019',
#  'Nov14_2019',
#  'Nov14_2_2019',
#  'Nov7_2019',
#  'test',
#  'test2_619.tif',
#  'test2_620.tif',
#  'test2_621.tif',
#  'test2_622.tif',
#  'test2_623.tif',
#  'test2_624.tif',
#  'test2_625.tif',
#  'test2_626.tif',
#  'test2_627.tif',
#  'test2_628.tif',
#  'test2_629.tif',
#  'test2_630.tif',
#  'test2_631.tif',
#  'test2_632.tif',
#  'test2_633.tif',
#  'test2_634.tif',
#  'test2_635.tif',
#  'test2_636.tif',
#  'test2_637.tif',
#  'test2_638.tif',
#  'test2_639.tif',
#  'test2_640.tif',
#  'test2_641.tif',
#  'test2_642.tif',
#  'test2_643.tif',
#  'test2_644.tif',
#  'test2_645.tif',
#  'test2_646.tif',
#  'test2_647.tif',
#  'test2_648.tif',
#  'test2_649.tif',
#  'test2_650.tif',
#  'test2_651.tif',
#  'test2_652.tif',
#  'test2_653.tif',
#  'test2_654.tif',
#  'test2_655.tif',
#  'test2_656.tif',
#  'test2_657.tif',
#  'test2_658.tif',
#  'test2_659.tif',
#  'test2_660.tif',
#  'test2_661.tif',
#  'test2_662.tif',
#  'test2_663.tif',
#  'test2_664.tif',
#  'test2_665.tif',
#  'test2_666.tif',
#  'test2_667.tif',
#  'test2_668.tif',
#  'test2_669.tif',
#  'test2_670.tif',
#  'test2_671.tif',
#  'test2_672.tif',
#  'test2_673.tif',
#  'test2_674.tif',
#  'test2_675.tif',
#  'test2_676.tif',
#  'test2_677.tif',
#  'test2_678.tif',
#  'test2_679.tif',
#  'test2_680.tif',
#  'test2_681.tif',
#  'test2_682.tif',
#  'test2_683.tif',
#  'test2_684.tif',
#  'test2_685.tif',
#  'test2_686.tif',
#  'test2_687.tif',
#  'test2_688.tif',
#  'test2_689.tif',
#  'test2_690.tif',
#  'test2_691.tif',
#  'test2_692.tif',
#  'test2_693.tif',
#  'test2_694.tif',
#  'test2_695.tif',
#  'test2_696.tif',
#  'test2_697.tif',
#  'test2_698.tif',
#  'test2_699.tif',
#  'test2_700.tif',
#  'test2_701.tif',
#  'test2_702.tif',
#  'test2_703.tif',
#  'test2_704.tif',
#  'test2_705.tif',
#  'test2_706.tif',
#  'test2_707.tif',
#  'test2_708.tif',
#  'test2_709.tif',
#  'test2_710.tif',
#  'test2_711.tif',
#  'test2_712.tif',
#  'test2_713.tif',
#  'test2_714.tif',
#  'test2_715.tif',
#  'test2_716.tif',
#  'test2_717.tif',
#  'test2_718.tif',
#  'test2_719.tif',
#  'test2_720.tif',
#  'test2_721.tif',
#  'test2_722.tif',
#  'test2_723.tif',
#  'test2_724.tif',
#  'test2_725.tif',
#  'test2_726.tif',
#  'test2_727.tif',
#  'test2_728.tif',
#  'test2_729.tif',
#  'test2_730.tif',
#  'test2_731.tif',
#  'test2_732.tif',
#  'test2_733.tif',
#  'test2_734.tif',
#  'test2_735.tif',
#  'test2_736.tif',
#  'test2_737.tif',
#  'test2_738.tif',
#  'test2_739.tif',
#  'test2_740.tif',
#  'test2_741.tif',
#  'test2_742.tif',
#  'test2_743.tif',
#  'test2_744.tif',
#  'test2_745.tif',
#  'test2_746.tif',
#  'test2_747.tif',
#  'test2_748.tif',
#  'test2_749.tif',
#  'test2_750.tif',
#  'test2_751.tif',
#  'test2_752.tif',
#  'test2_753.tif',
#  'test2_754.tif',
#  'test2_755.tif',
#  'test2_756.tif',
#  'test2_757.tif',
#  'test2_758.tif',
#  'test2_759.tif',
#  'test2_760.tif',
#  'test2_761.tif',
#  'test2_762.tif',
#  'test2_763.tif',
#  'test2_764.tif',
#  'test2_765.tif',
#  'test2_766.tif',
#  'test2_767.tif',
#  'test2_768.tif',
#  'test2_769.tif',
#  'test2_770.tif',
#  'test2_771.tif',
#  'test2_772.tif',
#  'test2_773.tif',
#  'test2_774.tif',
#  'test2_775.tif',
#  'test2_776.tif',
#  'test2_777.tif',
#  'test2_778.tif',
#  'test2_779.tif',
#  'test2_780.tif',
#  'test2_781.tif',
#  'test2_782.tif',
#  'test2_783.tif',
#  'test2_784.tif',
#  'test2_785.tif',
#  'test2_786.tif',
#  'test2_787.tif',
#  'test2_788.tif',
#  'test2_789.tif',
#  'test2_790.tif',
#  'test2_791.tif',
#  'test2_792.tif',
#  'test2_793.tif',
#  'test2_794.tif',
#  'test2_795.tif',
#  'test2_796.tif',
#  'test2_797.tif',
#  'test2_798.tif',
#  'test2_799.tif',
#  'test2_800.tif',
#  'test2_801.tif',
#  'test2_802.tif',
#  'test2_803.tif',
#  'test2_804.tif',
#  'test2_805.tif',
#  'test2_806.tif',
#  'test2_807.tif',
#  'test2_808.tif',
#  'test2_809.tif',
#  'test2_810.tif',
#  'test2_811.tif',
#  'test2_812.tif',
#  'test2_813.tif',
#  'test2_814.tif',
#  'test2_815.tif',
#  'test2_816.tif',
#  'test2_817.tif',
#  'test2_818.tif',
#  'test2_819.tif',
#  'test2_820.tif']

# %%
# ob_loc = "/HFIR/CG1D/IPTS-"+ipts+"/raw/ob"
ob_loc = "/HFIR/CG1D/IPTS-"+ipts+"/raw/radiographs"
sorted(os.listdir(ob_loc))
# Out:
# ['06_29_21_OB',
#  '06_29_21_dark_field',
#  '2021_02_25',
#  '2021_03_25',
#  '2021_04_12',
#  '2021_04_14',
#  '2021_04_15',
#  '2021_04_18_resolution',
#  '2021_04_22_25um_scint',
#  '2021_04_22_BN_PLA',
#  '2021_04_27_light',
#  '2021_05_25',
#  '2021_07_07_Cu_fastCT',
#  '2021_07_07_Cu_fastCT01',
#  '2021_07_26',
#  '2021_07_26_super_res',
#  '2021_09_04_mono_test',
#  '2022_01_04_flux',
#  '2022_01_04_stability',
#  '2022_01_09_stability',
#  '2022_01_13_neutron_eater',
#  '2022_01_23_recover_from_slits',
#  '2022_09_29_startup',
#  '2022_11_08_intensity_check',
#  '2023_05_23_QHYS',
#  '2023_05_23_QHYS_Choppers',
#  '2023_05_23_QHYS_gain_tuning',
#  '2023_05_24_VENUS_chopper',
#  '2023_08_29_beamsize',
#  '2023_08_29_cycle503',
#  '2024_01_22_QHY_resolution',
#  '2024_03_15_QHYL_1X_test_resolution',
#  '2024_03_15_idealVac_plate',
#  '2024_04_09_cycle_506',
#  '2024_04_09_cycle_506_',
#  '2024_04_09_cycle_506_8mm',
#  '2024_06_10_comm_test',
#  '2024_06_11_comm_test',
#  '2024_06_20_BM_calibration',
#  '2024_06_20_QHY_resolution',
#  '2024_06_24_QHYL_resolution',
#  '2024_06_28_O_ring',
#  '2024_07_23_optics_scan_3mmAperture_vert_all_10s',
#  '2024_07_23_optics_scan_pinhole_vert60mm_10s',
#  '2024_07_23_optics_scan_withDiffuser_60mmVertTrans_pinhole_10s',
#  '2024_07_23_optics_scan_woDiffuser_11mmPinhole_VertTrans_10s',
#  '2024_07_23_optics_scan_woDiffuser_16mmPinhole_VertTrans_5s',
#  '2024_07_23_optics_scan_woDiffuser_3mmPinhole_VertTrans_10s',
#  '2024_07_23_optics_scan_woDiffuser_60mmVertTrans_pinhole_10s',
#  '2024_07_23_optics_scan_woDiffuser_60mmVertTrans_pinhole_30s_redo',
#  '2024_07_23_optics_scan_woDiffuser_60mmVertTrans_pinhole_60s',
#  '2024_07_23_optics_scan_woDiffuser_85mmVertTrans_pinhole_10s',
#  '2024_07_23_test_QHYL',
#  '2024_08_07_flux',
#  '2024_10_15',
#  '2024_10_15_imaging_metrics_resolution_QHYL',
#  '2024_10_18_imaging_metrics_resolution_QHYL',
#  'Aug19_2020',
#  'DF_with_light_leak',
#  'Dec17_2019',
#  'Jan03_2020',
#  'Jan30_2020',
#  'Jan31_2020',
#  'July02_2020',
#  'June18_2020',
#  'June19_2020',
#  'June23_2020',
#  'June_15_2020',
#  'MattTest',
#  'Nov11_2019',
#  'Nov14_2019',
#  'Nov14_2_2019',
#  'Nov7_2019',
#  'test',
#  'test2_619.tif',
#  'test2_620.tif',
#  'test2_621.tif',
#  'test2_622.tif',
#  'test2_623.tif',
#  'test2_624.tif',
#  'test2_625.tif',
#  'test2_626.tif',
#  'test2_627.tif',
#  'test2_628.tif',
#  'test2_629.tif',
#  'test2_630.tif',
#  'test2_631.tif',
#  'test2_632.tif',
#  'test2_633.tif',
#  'test2_634.tif',
#  'test2_635.tif',
#  'test2_636.tif',
#  'test2_637.tif',
#  'test2_638.tif',
#  'test2_639.tif',
#  'test2_640.tif',
#  'test2_641.tif',
#  'test2_642.tif',
#  'test2_643.tif',
#  'test2_644.tif',
#  'test2_645.tif',
#  'test2_646.tif',
#  'test2_647.tif',
#  'test2_648.tif',
#  'test2_649.tif',
#  'test2_650.tif',
#  'test2_651.tif',
#  'test2_652.tif',
#  'test2_653.tif',
#  'test2_654.tif',
#  'test2_655.tif',
#  'test2_656.tif',
#  'test2_657.tif',
#  'test2_658.tif',
#  'test2_659.tif',
#  'test2_660.tif',
#  'test2_661.tif',
#  'test2_662.tif',
#  'test2_663.tif',
#  'test2_664.tif',
#  'test2_665.tif',
#  'test2_666.tif',
#  'test2_667.tif',
#  'test2_668.tif',
#  'test2_669.tif',
#  'test2_670.tif',
#  'test2_671.tif',
#  'test2_672.tif',
#  'test2_673.tif',
#  'test2_674.tif',
#  'test2_675.tif',
#  'test2_676.tif',
#  'test2_677.tif',
#  'test2_678.tif',
#  'test2_679.tif',
#  'test2_680.tif',
#  'test2_681.tif',
#  'test2_682.tif',
#  'test2_683.tif',
#  'test2_684.tif',
#  'test2_685.tif',
#  'test2_686.tif',
#  'test2_687.tif',
#  'test2_688.tif',
#  'test2_689.tif',
#  'test2_690.tif',
#  'test2_691.tif',
#  'test2_692.tif',
#  'test2_693.tif',
#  'test2_694.tif',
#  'test2_695.tif',
#  'test2_696.tif',
#  'test2_697.tif',
#  'test2_698.tif',
#  'test2_699.tif',
#  'test2_700.tif',
#  'test2_701.tif',
#  'test2_702.tif',
#  'test2_703.tif',
#  'test2_704.tif',
#  'test2_705.tif',
#  'test2_706.tif',
#  'test2_707.tif',
#  'test2_708.tif',
#  'test2_709.tif',
#  'test2_710.tif',
#  'test2_711.tif',
#  'test2_712.tif',
#  'test2_713.tif',
#  'test2_714.tif',
#  'test2_715.tif',
#  'test2_716.tif',
#  'test2_717.tif',
#  'test2_718.tif',
#  'test2_719.tif',
#  'test2_720.tif',
#  'test2_721.tif',
#  'test2_722.tif',
#  'test2_723.tif',
#  'test2_724.tif',
#  'test2_725.tif',
#  'test2_726.tif',
#  'test2_727.tif',
#  'test2_728.tif',
#  'test2_729.tif',
#  'test2_730.tif',
#  'test2_731.tif',
#  'test2_732.tif',
#  'test2_733.tif',
#  'test2_734.tif',
#  'test2_735.tif',
#  'test2_736.tif',
#  'test2_737.tif',
#  'test2_738.tif',
#  'test2_739.tif',
#  'test2_740.tif',
#  'test2_741.tif',
#  'test2_742.tif',
#  'test2_743.tif',
#  'test2_744.tif',
#  'test2_745.tif',
#  'test2_746.tif',
#  'test2_747.tif',
#  'test2_748.tif',
#  'test2_749.tif',
#  'test2_750.tif',
#  'test2_751.tif',
#  'test2_752.tif',
#  'test2_753.tif',
#  'test2_754.tif',
#  'test2_755.tif',
#  'test2_756.tif',
#  'test2_757.tif',
#  'test2_758.tif',
#  'test2_759.tif',
#  'test2_760.tif',
#  'test2_761.tif',
#  'test2_762.tif',
#  'test2_763.tif',
#  'test2_764.tif',
#  'test2_765.tif',
#  'test2_766.tif',
#  'test2_767.tif',
#  'test2_768.tif',
#  'test2_769.tif',
#  'test2_770.tif',
#  'test2_771.tif',
#  'test2_772.tif',
#  'test2_773.tif',
#  'test2_774.tif',
#  'test2_775.tif',
#  'test2_776.tif',
#  'test2_777.tif',
#  'test2_778.tif',
#  'test2_779.tif',
#  'test2_780.tif',
#  'test2_781.tif',
#  'test2_782.tif',
#  'test2_783.tif',
#  'test2_784.tif',
#  'test2_785.tif',
#  'test2_786.tif',
#  'test2_787.tif',
#  'test2_788.tif',
#  'test2_789.tif',
#  'test2_790.tif',
#  'test2_791.tif',
#  'test2_792.tif',
#  'test2_793.tif',
#  'test2_794.tif',
#  'test2_795.tif',
#  'test2_796.tif',
#  'test2_797.tif',
#  'test2_798.tif',
#  'test2_799.tif',
#  'test2_800.tif',
#  'test2_801.tif',
#  'test2_802.tif',
#  'test2_803.tif',
#  'test2_804.tif',
#  'test2_805.tif',
#  'test2_806.tif',
#  'test2_807.tif',
#  'test2_808.tif',
#  'test2_809.tif',
#  'test2_810.tif',
#  'test2_811.tif',
#  'test2_812.tif',
#  'test2_813.tif',
#  'test2_814.tif',
#  'test2_815.tif',
#  'test2_816.tif',
#  'test2_817.tif',
#  'test2_818.tif',
#  'test2_819.tif',
#  'test2_820.tif']

# %%
dc_loc = "/HFIR/CG1D/IPTS-"+ipts+"/raw/dc"
sorted(os.listdir(dc_loc))
# Out:
# ['2022_11_08_QHY',
#  '2023_05_24',
#  '2023_08_29_30s',
#  '2024_01_21_45s',
#  '2024_04_09_cycle_506',
#  '2024_06_20_DC_60s',
#  '2024_10_15_DC_108s',
#  '2024_10_15_DC_28s',
#  '2024_10_15_DC_432s',
#  '2024_10_15_DC_60s',
#  '2024_10_15_DC_667s',
#  '2024_10_18_DC_667s',
#  'test']

# %%
###################### need to change start
sample_name = "2024_10_18_imaging_metrics_resolution_QHYL"
scan_dir = os.path.join(scan_loc, sample_name)
ob_dir = os.path.join(ob_loc, "2024_10_18_imaging_metrics_resolution_QHYL")
dc_dir = os.path.join(dc_loc, "2024_10_18_DC_667s")
# ct_dir = "/HFIR/CG1D/IPTS-"+ipts+"/shared/processed_data/raw_to_recon"
# ob_dir = "/HFIR/CG1D/IPTS-"+ipts+"/shared/processed_data/raw_to_recon"
# dc_dir = "/HFIR/CG1D/IPTS-"+ipts+"/shared/processed_data/raw_to_recon"
ob_name = "*OB*" # Will not be used if follows the default file structure
dc_name = "*DC*" # Will not be used if follows the default file structure
gamma_diff = 20
###################### need to change end

# %% [markdown]
# # Preprocess scan files

# %%
fname_list = os.listdir(scan_dir)
# fname_list.pop(0)
fname_list.sort()
print(len(fname_list))
fname_list
# Out:
# 140
# ['scan00_SampleZ_OB_pinhole033_0667_0001.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0002.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0003.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0004.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0005.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0001.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0002.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0003.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0004.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0005.tiff',
#  'scan00_SampleZ_pinhole033_128.000_0667_0011.tiff',
#  'scan00_SampleZ_pinhole033_128.000_0667_0012.tiff',
#  'scan00_SampleZ_pinhole033_128.000_0667_0014.tiff',
#  'scan00_SampleZ_pinhole033_128.000_0667_0015.tiff',
#  'scan00_SampleZ_pinhole033_178.000_0667_0016.tiff',
#  'scan00_SampleZ_pinhole033_178.000_0667_0017.tiff',
#  'scan00_SampleZ_pinhole033_178.000_0667_0018.tiff',
#  'scan00_SampleZ_pinhole033_178.000_0667_0019.tiff',
#  'scan00_SampleZ_pinhole033_178.000_0667_0020.tiff',
#  'scan00_SampleZ_pinhole033_228.000_0667_0021.tiff',
#  'scan00_SampleZ_pinhole033_228.000_0667_0022.tiff',
#  'scan00_SampleZ_pinhole033_228.000_0667_0023.tiff',
#  'scan00_SampleZ_pinhole033_228.000_0667_0024.tiff',
#  'scan00_SampleZ_pinhole033_228.000_0667_0025.tiff',
#  'scan00_SampleZ_pinhole033_278.000_0667_0026.tiff',
#  'scan00_SampleZ_pinhole033_278.000_0667_0027.tiff',
#  'scan00_SampleZ_pinhole033_278.000_0667_0028.tiff',
#  'scan00_SampleZ_pinhole033_278.000_0667_0029.tiff',
#  'scan00_SampleZ_pinhole033_278.000_0667_0030.tiff',
#  'scan00_SampleZ_pinhole033_78.000_0667_0006.tiff',
#  'scan00_SampleZ_pinhole033_78.000_0667_0007.tiff',
#  'scan00_SampleZ_pinhole033_78.000_0667_0008.tiff',
#  'scan00_SampleZ_pinhole033_78.000_0667_0009.tiff',
#  'scan00_SampleZ_pinhole033_78.000_0667_0010.tiff']

# %%
to_rmv = [
# '090624_4batterystack_Radio1_0060_0587.tiff',
#  '090624_4batterystack_Radio1_0060_0588.tiff',
#  '090624_4batterystack_Radio1_0060_0589.tiff',
#     '090624_4batterystack_Radio1_0600_0590.tiff'
#  '20230919_dry_spun_fibers_rejoint_0300_0021.tiff',
#  '20230919_dry_spun_fibers_rejoint_0300_0022.tiff',
#  '20230919_dry_spun_fibers_rejoint_0300_0023.tiff',
#  '20230919_wet_spun_fibers_0300_0006.tiff',
#  '20230919_wet_spun_fibers_0300_0007.tiff',
#  '20230919_wet_spun_fibers_0300_0008.tiff',
]
fname_list = rocku.remove_fnames(fname_list, to_rmv)
# Out:
# 25
# 25

# %%
ob_list = os.listdir(ob_dir)
# fname_list.pop(0)
ob_list.sort()
print(len(ob_list))
# ob_list = ob_list[:3]
ob_list
# Out:
# 140
# ['scan00_SampleZ_OB_pinhole033_0667_0001.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0002.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0003.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0004.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0005.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0001.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0002.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0003.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0004.tiff',
#  'scan00_SampleZ_OB_pinhole041_0432_0005.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0003.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0004.tiff',
#  'scan00_SampleZ_OB_pinhole033_0667_0005.tiff']

# %%
to_rmv = [
# 'OB_0060_1578.tiff',
#  'OB_0060_1579.tiff',
#  'OB_0060_1580.tiff',
#  'OB_0060_1581.tiff',
#  'OB_0060_1582.tiff',
#  'OB_0060_1583.tiff',
#  'OB_0060_1584.tiff',
#  'OB_0060_1585.tiff',
#  'OB_0060_1586.tiff',
#  'OB_0060_1587.tiff',
#  'OB_0060_1588.tiff',
#  'OB_0060_1589.tiff',
#  'OB_0060_1590.tiff',
#  'OB_0060_1591.tiff',
#  'OB_0060_1592.tiff',
]
ob_list = rocku.remove_fnames(ob_list, to_rmv)
# Out:
# 5
# 5

# %%
dc_list = os.listdir(dc_dir)
# fname_list.pop(0)
dc_list.sort()
print(len(dc_list))
dc_list
# Out:
# 5
# ['DC_0667_1282.tiff',
#  'DC_0667_1283.tiff',
#  'DC_0667_1284.tiff',
#  'DC_0667_1285.tiff',
#  'DC_0667_1286.tiff']

# %%
to_rmv = [
]
dc_list = rocku.remove_fnames(dc_list, to_rmv)
# Out:
# 5
# 5

# %%
######### Scan
scan_raw = rocku.read_tiff_stack(scan_dir, fname_list)
print(scan_raw.shape)
######### OB
ob_raw = rocku.read_tiff_stack(ob_dir, ob_list)
print(ob_raw.shape)
######### DC
dc_raw = rocku.read_tiff_stack(dc_dir, dc_list)
print(dc_raw.shape)
# Out:
# 25
# 25it [00:12,  1.97it/s]
# (25, 6200, 6200)
# 5
# 5it [00:01,  3.15it/s]
# (5, 6200, 6200)
# 5
# 5it [00:03,  1.36it/s]
# (5, 6200, 6200)

# %%
scan_min = np.min(scan_raw, axis=0)
ob_min = np.min(ob_raw, axis=0)
dc_max = np.max(dc_raw, axis=0)
plt.imshow(scan_min)
plt.colorbar()
plt.show()
plt.imshow(ob_min)
plt.colorbar()
plt.show()
plt.imshow(dc_max)
plt.colorbar()
plt.show()

# %% [markdown]
# # Crop ROI

# %%
###################### need to change start
crop = True
# crop = False
crop_left = 350#320
crop_right = -400#1080
crop_top = 400
crop_bottom = -150
# crop_left = 2500
# crop_right = 4500
# crop_top = 200
# crop_bottom = 2350
###################### need to change end
scan_crop = rocku.crop(scan_raw, crop_left, crop_right, crop_top, crop_bottom, crop)
ob_crop = rocku.crop(ob_raw, crop_left, crop_right, crop_top, crop_bottom, crop)
dc_crop = rocku.crop(dc_raw, crop_left, crop_right, crop_top, crop_bottom, crop)
scan_crop_min = rocku.crop(scan_min, crop_left, crop_right, crop_top, crop_bottom, crop)
print("Recon ROI:")
plt.imshow(scan_crop_min, vmin=0, vmax=8000)
plt.colorbar()
plt.show()
# Out:
# Recon ROI:

# %% [markdown]
# # Removal outliers

# %%
t0 = timeit.default_timer()
scan_crop = tomopy.misc.corr.remove_outlier_cuda(scan_crop, gamma_diff).astype(np.ushort)
ob_crop = tomopy.misc.corr.remove_outlier_cuda(ob_crop, gamma_diff).astype(np.ushort)
dc_crop = tomopy.misc.corr.remove_outlier_cuda(dc_crop, gamma_diff).astype(np.ushort)
t1 = timeit.default_timer()
print("Time: {} s".format(t1-t0))
# Out:
# Time: 9.408085595816374 s

# %% [markdown]
# # Bin images

# %%
bin_size = 5
#####################
#####################
if bin_size != 1:
    to_rmv = len(fname_list)%bin_size
    if to_rmv == 0:
        fname_list_rmv = fname_list[:]
        scan_crop_rmv = scan_crop[:]
    else:
        fname_list_rmv = fname_list[:-to_rmv]
        scan_crop_rmv = scan_crop[:-to_rmv]
    fname_list_bin = fname_list_rmv[0::bin_size]
    scan_crop_bin = np.array([np.mean(scan_crop_rmv[i:i+bin_size], axis=0) for i in tqdm(range(0, len(scan_crop_rmv), bin_size))])
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  9.78it/s]

# %% [markdown]
# # Normalization

# %%
#####################
#####################
if bin_size != 1:
    scan_norm, scan_mi_dc, ob_mi_dc, dc_med = rocku.normalize(scan_crop_bin, ob_crop, dc_crop)
else:
    scan_norm, scan_mi_dc, ob_mi_dc, dc_med = rocku.normalize(scan_crop, ob_crop, dc_crop)
print(scan_norm.dtype)
print(scan_norm.shape)
plt.imshow(scan_norm[0], vmin=0, vmax=1)
# plt.imshow(scan_norm[0])
plt.colorbar()
plt.show()
# Out:
# OB stack combined by median.
# DC stack combined by median.
# Normalization Done!
# float32
# (5, 5650, 5450)

# %% [markdown]
# # Check if OB has changed

# %%
# reg_ob = True
reg_ob = False
reg_left = 100#320
reg_right = -100#1080
reg_top = 900
reg_bottom = 1200
###################### need to change end
if reg_ob:
    scan_norm_unreg_roi = rocku.crop(scan_norm, reg_left, reg_right, reg_top, reg_bottom, reg_ob)
    scan_unreg_roi = rocku.crop(scan_mi_dc, reg_left, reg_right, reg_top, reg_bottom, reg_ob)
    ob_unreg_roi = rocku.crop(ob_mi_dc, reg_left, reg_right, reg_top, reg_bottom, reg_ob)
    
    f, ax = plt.subplots(1, 2, figsize=(20, 20))
    ax[0].imshow(scan_norm_unreg_roi[0])
    ax[0].set_title('first image')
    
    ax[1].imshow(scan_norm_unreg_roi[-1])
    ax[1].set_title('last image')

# %%
if reg_ob:
    trans_algo_dict = {
        'TRANSLATION': StackReg.TRANSLATION,
        'RIGID_BODY': StackReg.RIGID_BODY,
        'SCALED_ROTATION': StackReg.SCALED_ROTATION,
        'AFFINE': StackReg.AFFINE,
        'BILINEAR': StackReg.BILINEAR
    }
    trans_algo = "RIGID_BODY"
    #########################
    #load reference and "moved" image
    ref = scan_unreg_roi[0]
    mov = ob_unreg_roi
    #########################
    sr = StackReg(trans_algo_dict[trans_algo])
    reg = sr.register_transform(ref, mov)
    # reg = reg.clip(min=0)
    
    f, ax = plt.subplots(1, 2, figsize=(20, 20))
    
    ax[0].imshow(scan_norm_unreg_roi[0])
    ax[0].set_title('Empty area before registering OB')
    ax[0].axis('off')
    
    ax[1].imshow(np.true_divide(ref, reg, dtype=np.float32))
    ax[1].set_title('Empty area after registering OB')
    ax[1].axis('off')

# %%
# Apply registration to full OB
if reg_ob:
    ob_mi_dc_reg = sr.transform(ob_mi_dc)
    scan_norm_reg = np.true_divide(scan_mi_dc, ob_mi_dc_reg, dtype=np.float32)
    f, ax = plt.subplots(1, 2, figsize=(20, 20))
    
    ax[0].imshow(scan_norm[0])
    ax[0].set_title('Before registering OB')
    ax[0].axis('off')
    
    ax[1].imshow(scan_norm_reg[0])
    ax[1].set_title('After registering OB')
    ax[1].axis('off')
else:
    scan_norm_reg = scan_norm[:]

# %% [markdown]
# # Beam fluctuation correction (optional)

# %%
###################### need to change start
fluc_corr = True
# fluc_corr = False
bg_left = 400
bg_right = 1000
bg_top = 2100
bg_bottom = 3000
###################### need to change end
if fluc_corr:
    bg_stack = scan_norm_reg[:, bg_top:bg_bottom, bg_left:bg_right]
    bg_min = np.min(bg_stack, axis=0)
    print("Beam fluctuation ROI:")
    plt.imshow(bg_min, vmin=0, vmax=1)
    plt.colorbar()
    plt.show()
# Out:
# Beam fluctuation ROI:

# %%
if fluc_corr:
    t0 = timeit.default_timer()
    scan_norm_reg = tomopy.prep.normalize.normalize_roi(scan_norm_reg, roi= [bg_top, bg_left, bg_bottom, bg_right], ncore=ncore)
    plt.imshow(scan_norm_reg[0], vmin=0, vmax=1)
    plt.colorbar()
    plt.show()
    t1 = timeit.default_timer()
    print("Time: {} s".format(t1-t0))
# Out:
# Time: 1.2508877832442522 s

# %% [markdown]
# # Crop output

# %%
###################### need to change start
# out_crop = True
out_crop = False
out_crop_left = 0#320
out_crop_right = 800#1080
out_crop_top = 0
out_crop_bottom = -1
###################### need to change end
scan_norm_out = rocku.crop(scan_norm_reg, out_crop_left, out_crop_right, out_crop_top, out_crop_bottom, out_crop)
print("Output ROI:")
plt.imshow(scan_norm_out[0], vmin=0, vmax=1)
plt.colorbar()
plt.show()
# Out:
# Output ROI:

# %%
t0 = timeit.default_timer()
scan_norm_out = tomopy.misc.corr.remove_outlier_cuda(scan_norm_out, 0.1) 
t1 = timeit.default_timer() 
print("Time: {} s".format(t1-t0))
plt.imshow(scan_norm_out[0], vmin=0, vmax=1)
plt.colorbar()
plt.show()
# Out:
# Time: 2.78041479177773 s

# %% [markdown]
# # Save files

# %%
################ change save path for your own
save_to = "/HFIR/CG1D/IPTS-"+ipts+"/shared/processed_data/normalized/" + sample_name# + '_Right'
if bin_size != 1:
    save_to = save_to + "_binned_by_" + str(bin_size)
    fname_list_save = fname_list_bin[:]
else:
    fname_list_save = fname_list[:]
print('Saving to {} ...'.format(save_to))
for i, e_name in tqdm(enumerate(fname_list_save)):
#     e_name = rocku.remove_1st_str(e_name)
    fname = save_to + "/" + e_name
    dxchange.write_tiff(scan_norm_out[i], fname=fname, overwrite=True)
# Out:
# Saving to /HFIR/CG1D/IPTS-23768/shared/processed_data/normalized/2024_10_18_imaging_metrics_resolution_QHYL_binned_by_5 ...
# 5it [00:01,  4.19it/s]
