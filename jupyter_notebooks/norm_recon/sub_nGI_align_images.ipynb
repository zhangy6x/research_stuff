# %%
import os
import utilities as rocku
import matplotlib.pyplot as plt
import numpy as np
import multiprocessing as mp
import timeit
from pystackreg import StackReg
from PIL import Image
from tqdm import tqdm

# %%
ncore = mp.cpu_count()
ncore
# Out:
# 64

# %%
# need to change
ipts="31969"
# scan_type = 'ct_scans'
# scan_type = 'radiographs'
scan_type = 'processed_data'
# scan_type = 'analysis'
# scan_type = 'analysis'
####################################
##################################
scan_loc = "/HFIR/CG1D/IPTS-"+ipts+"/shared/" + scan_type
folder_list = os.listdir(scan_loc)
folder_list.sort()
folder_list
# Out:
# ['2023_09_05_C123_coarse', '2023_09_05_M123']

# %%
sample_name = "2023_09_05_C123_coarse"
# distance_to_G2_cm = 1.6
distance_to_G2_cm = 0.5
reverse = True
######################
wavelen_ang = 2.5
period_um = 56.5
name_pattern = ["TI_ACL", "DFI_ACL", "DPC_ACL"]
ref_name = name_pattern[0]
######################
######################
######################
scan_dir = os.path.join(scan_loc, sample_name)
fname_list = os.listdir(scan_dir)
fname_list.sort()
fname_dict = {}
for e_pa in name_pattern:
    _fname_list = rocku.filter_list(fname_list, e_pa)
    _fname_list.sort(reverse=reverse)
    fname_dict[e_pa] = _fname_list
pos_list = []
for each in fname_dict[name_pattern[0]]:
    _n = each.split('.')[0]
    _num = int(_n.split('_')[-1])
    pos_list.append(_num)
######################
fname_dict_out = {}
acl_list = []
pos_max = max(pos_list)
for e_pos in pos_list:
    _acl_nm = int(1000*wavelen_ang*((pos_max-e_pos)/10 + distance_to_G2_cm)/period_um)
    acl_list.append("{:04d}".format(_acl_nm) + "nm")
for e_pa in name_pattern:
    _fname_list_out = []
    for e_acl in acl_list:
        _fname_list_out.append("_".join([e_pa, e_acl]))
    fname_dict_out[e_pa] = _fname_list_out
for ea_pa in name_pattern:
    print(ea_pa)
    for m, ea_file in enumerate(fname_dict[ea_pa]):
        print("'{}' converted to '{}'".format(ea_file, fname_dict_out[ea_pa][m]))
# Out:
# TI_ACL
# 'TI_ACL_197.fits' converted to 'TI_ACL_0022nm'
# 'TI_ACL_195.fits' converted to 'TI_ACL_0030nm'
# 'TI_ACL_185.fits' converted to 'TI_ACL_0075nm'
# 'TI_ACL_175.fits' converted to 'TI_ACL_0119nm'
# 'TI_ACL_165.fits' converted to 'TI_ACL_0163nm'
# 'TI_ACL_155.fits' converted to 'TI_ACL_0207nm'
# 'TI_ACL_145.fits' converted to 'TI_ACL_0252nm'
# 'TI_ACL_135.fits' converted to 'TI_ACL_0296nm'
# 'TI_ACL_125.fits' converted to 'TI_ACL_0340nm'
# 'TI_ACL_115.fits' converted to 'TI_ACL_0384nm'
# 'TI_ACL_105.fits' converted to 'TI_ACL_0429nm'
# 'TI_ACL_095.fits' converted to 'TI_ACL_0473nm'
# 'TI_ACL_085.fits' converted to 'TI_ACL_0517nm'
# 'TI_ACL_075.fits' converted to 'TI_ACL_0561nm'
# 'TI_ACL_065.fits' converted to 'TI_ACL_0606nm'
# 'TI_ACL_055.fits' converted to 'TI_ACL_0650nm'
# 'TI_ACL_045.fits' converted to 'TI_ACL_0694nm'
# 'TI_ACL_035.fits' converted to 'TI_ACL_0738nm'
# 'TI_ACL_025.fits' converted to 'TI_ACL_0783nm'
# 'TI_ACL_015.fits' converted to 'TI_ACL_0827nm'
# 'TI_ACL_005.fits' converted to 'TI_ACL_0871nm'
# 'TI_ACL_002.fits' converted to 'TI_ACL_0884nm'
# DFI_ACL
# 'DFI_ACL_197.fits' converted to 'DFI_ACL_0022nm'
# 'DFI_ACL_195.fits' converted to 'DFI_ACL_0030nm'
# 'DFI_ACL_185.fits' converted to 'DFI_ACL_0075nm'
# 'DFI_ACL_175.fits' converted to 'DFI_ACL_0119nm'
# 'DFI_ACL_165.fits' converted to 'DFI_ACL_0163nm'
# 'DFI_ACL_155.fits' converted to 'DFI_ACL_0207nm'
# 'DFI_ACL_145.fits' converted to 'DFI_ACL_0252nm'
# 'DFI_ACL_135.fits' converted to 'DFI_ACL_0296nm'
# 'DFI_ACL_125.fits' converted to 'DFI_ACL_0340nm'
# 'DFI_ACL_115.fits' converted to 'DFI_ACL_0384nm'
# 'DFI_ACL_105.fits' converted to 'DFI_ACL_0429nm'
# 'DFI_ACL_095.fits' converted to 'DFI_ACL_0473nm'
# 'DFI_ACL_085.fits' converted to 'DFI_ACL_0517nm'
# 'DFI_ACL_075.fits' converted to 'DFI_ACL_0561nm'
# 'DFI_ACL_065.fits' converted to 'DFI_ACL_0606nm'
# 'DFI_ACL_055.fits' converted to 'DFI_ACL_0650nm'
# 'DFI_ACL_045.fits' converted to 'DFI_ACL_0694nm'
# 'DFI_ACL_035.fits' converted to 'DFI_ACL_0738nm'
# 'DFI_ACL_025.fits' converted to 'DFI_ACL_0783nm'
# 'DFI_ACL_015.fits' converted to 'DFI_ACL_0827nm'
# 'DFI_ACL_005.fits' converted to 'DFI_ACL_0871nm'
# 'DFI_ACL_002.fits' converted to 'DFI_ACL_0884nm'
# DPC_ACL
# 'DPC_ACL_197.fits' converted to 'DPC_ACL_0022nm'
# 'DPC_ACL_195.fits' converted to 'DPC_ACL_0030nm'
# 'DPC_ACL_185.fits' converted to 'DPC_ACL_0075nm'
# 'DPC_ACL_175.fits' converted to 'DPC_ACL_0119nm'
# 'DPC_ACL_165.fits' converted to 'DPC_ACL_0163nm'
# 'DPC_ACL_155.fits' converted to 'DPC_ACL_0207nm'
# 'DPC_ACL_145.fits' converted to 'DPC_ACL_0252nm'
# 'DPC_ACL_135.fits' converted to 'DPC_ACL_0296nm'
# 'DPC_ACL_125.fits' converted to 'DPC_ACL_0340nm'
# 'DPC_ACL_115.fits' converted to 'DPC_ACL_0384nm'
# 'DPC_ACL_105.fits' converted to 'DPC_ACL_0429nm'
# 'DPC_ACL_095.fits' converted to 'DPC_ACL_0473nm'
# 'DPC_ACL_085.fits' converted to 'DPC_ACL_0517nm'
# 'DPC_ACL_075.fits' converted to 'DPC_ACL_0561nm'
# 'DPC_ACL_065.fits' converted to 'DPC_ACL_0606nm'
# 'DPC_ACL_055.fits' converted to 'DPC_ACL_0650nm'
# 'DPC_ACL_045.fits' converted to 'DPC_ACL_0694nm'
# 'DPC_ACL_035.fits' converted to 'DPC_ACL_0738nm'
# 'DPC_ACL_025.fits' converted to 'DPC_ACL_0783nm'
# 'DPC_ACL_015.fits' converted to 'DPC_ACL_0827nm'
# 'DPC_ACL_005.fits' converted to 'DPC_ACL_0871nm'
# 'DPC_ACL_002.fits' converted to 'DPC_ACL_0884nm'

# %%
unreg_dict = {}
for e_pa in name_pattern:
    print("Loading {} ...".format(e_pa))
    _img_stack = rocku.read_img_stack(scan_dir, fname_dict[e_pa], flipud=True)
    unreg_dict[e_pa] = _img_stack.astype(np.float32)
# Out:
# Loading TI_ACL ...
# 22it [00:00, 58.92it/s]
# Loading DFI_ACL ...
# 22it [00:00, 76.40it/s]
# Loading DPC_ACL ...
# 22it [00:00, 64.93it/s]

# %%
# img_min = np.min(unreg_dict[name_pattern[0]], axis=0)

f, ax = plt.subplots(1, 2, figsize=(20, 20))
ax[0].imshow(unreg_dict[ref_name][0])
ax[0].set_title('first image')

ax[1].imshow(unreg_dict[ref_name][-1])
ax[1].set_title('last image')

# ax[2].imshow(img_min)
# ax[2].set_title('np.min')
# Out:
# Text(0.5, 1.0, 'np.min')

# %%
###################### need to change start
crop = True
# crop_left = 250
# crop_right = 1650
# crop_top = 750
# crop_bottom = 1950
crop_left = 0
crop_right = 1850
crop_top = 0
crop_bottom = 700
###################### need to change end
# proj_crop = rocku.crop(proj_raw, crop_left, crop_right, crop_top, crop_bottom, crop)
# ob_crop = rocku.crop(ob_raw, crop_left, crop_right, crop_top, crop_bottom, crop)
# dc_crop = rocku.crop(dc_raw, crop_left, crop_right, crop_top, crop_bottom, crop)
first_crop = rocku.crop(unreg_dict[ref_name][0], crop_left, crop_right, crop_top, crop_bottom, crop)
last_crop = rocku.crop(unreg_dict[ref_name][-1], crop_left, crop_right, crop_top, crop_bottom, crop)
img_min_crop = rocku.crop(img_min, crop_left, crop_right, crop_top, crop_bottom, crop)

f, ax = plt.subplots(1, 3, figsize=(20, 20))
ax[0].imshow(first_crop)
ax[0].set_title('first image')

ax[1].imshow(last_crop)
ax[1].set_title('last image')

ax[2].imshow(img_min_crop)
ax[2].set_title('np.min')
# Out:
# Text(0.5, 1.0, 'np.min')

# %%
for ea_pa in name_pattern:
    unreg_dict[ea_pa] = rocku.crop(unreg_dict[ea_pa], crop_left, crop_right, crop_top, crop_bottom, crop)
trans_algo_dict = {
    'TRANSLATION': StackReg.TRANSLATION,
    'RIGID_BODY': StackReg.RIGID_BODY,
    'SCALED_ROTATION': StackReg.SCALED_ROTATION,
    'AFFINE': StackReg.AFFINE,
    'BILINEAR': StackReg.BILINEAR
}

# %%
trans_algo = "SCALED_ROTATION"
#########################
#load reference and "moved" image
ref = unreg_dict[ref_name][0]
mov = unreg_dict[ref_name][-1]
#########################
sr = StackReg(trans_algo_dict[trans_algo])
reg = sr.register_transform(ref, mov)
reg = reg.clip(min=0)
after_reg = rocku.composite_images([ref, reg])
before_reg = rocku.composite_images([ref, mov])

f, ax = plt.subplots(2, 2, figsize=(20, 20))
ax[0][0].imshow(ref, cmap='gray')
ax[0][0].set_title('reference image')
ax[0][0].axis('off')

ax[0][1].imshow(mov, cmap='gray')
ax[0][1].set_title('changed image')
ax[0][1].axis('off')

ax[1][0].imshow(before_reg)
ax[1][0].set_title('overlay (reference=green, changed=red)')
ax[1][0].axis('off');

ax[1][1].imshow(after_reg)
ax[1][1].set_title('overlay (reference=green, changed=red)')
ax[1][1].axis('off');

# %%
sr = StackReg(trans_algo_dict[trans_algo])
size = (unreg_dict[ref_name].shape[0], unreg_dict[ref_name].shape[1], unreg_dict[ref_name].shape[2])
reg_dict = {}
for e_pa in name_pattern:
    reg_dict[e_pa] = np.empty(size, dtype=unreg_dict[e_pa].dtype)
    reg_dict[e_pa][0] = unreg_dict[e_pa][0][:]
for idx in range(size[0]):
    if idx != 0:
        print("Registering {}".format(fname_dict[ref_name][idx]))
        _reg = sr.register_transform(unreg_dict[ref_name][0], unreg_dict[ref_name][idx])
        _reg = _reg.clip(min=0)
        reg_dict[ref_name][idx] = _reg[:]
        for ee in name_pattern:
            if ee != ref_name:
                print("Apply transform to {}".format(fname_dict[ee][idx]))
                _reg_trans = sr.transform(unreg_dict[ee][idx])
                reg_dict[ee][idx] = _reg_trans[:]
# Out:
# Registering TI_ACL_195.fits
# Apply transform to DFI_ACL_195.fits
# Apply transform to DPC_ACL_195.fits
# Registering TI_ACL_185.fits
# Apply transform to DFI_ACL_185.fits
# Apply transform to DPC_ACL_185.fits
# Registering TI_ACL_175.fits
# Apply transform to DFI_ACL_175.fits
# Apply transform to DPC_ACL_175.fits
# Registering TI_ACL_165.fits
# Apply transform to DFI_ACL_165.fits
# Apply transform to DPC_ACL_165.fits
# Registering TI_ACL_155.fits
# Apply transform to DFI_ACL_155.fits
# Apply transform to DPC_ACL_155.fits
# Registering TI_ACL_145.fits
# Apply transform to DFI_ACL_145.fits
# Apply transform to DPC_ACL_145.fits
# Registering TI_ACL_135.fits
# Apply transform to DFI_ACL_135.fits
# Apply transform to DPC_ACL_135.fits
# Registering TI_ACL_125.fits
# Apply transform to DFI_ACL_125.fits
# Apply transform to DPC_ACL_125.fits
# Registering TI_ACL_115.fits
# Apply transform to DFI_ACL_115.fits
# Apply transform to DPC_ACL_115.fits
# Registering TI_ACL_105.fits
# Apply transform to DFI_ACL_105.fits
# Apply transform to DPC_ACL_105.fits
# Registering TI_ACL_095.fits
# Apply transform to DFI_ACL_095.fits
# Apply transform to DPC_ACL_095.fits
# Registering TI_ACL_085.fits
# Apply transform to DFI_ACL_085.fits
# Apply transform to DPC_ACL_085.fits
# Registering TI_ACL_075.fits
# Apply transform to DFI_ACL_075.fits
# Apply transform to DPC_ACL_075.fits
# Registering TI_ACL_065.fits
# Apply transform to DFI_ACL_065.fits
# Apply transform to DPC_ACL_065.fits
# Registering TI_ACL_055.fits
# Apply transform to DFI_ACL_055.fits
# Apply transform to DPC_ACL_055.fits
# Registering TI_ACL_045.fits
# Apply transform to DFI_ACL_045.fits
# Apply transform to DPC_ACL_045.fits
# Registering TI_ACL_035.fits
# Apply transform to DFI_ACL_035.fits
# Apply transform to DPC_ACL_035.fits
# Registering TI_ACL_025.fits
# Apply transform to DFI_ACL_025.fits
# Apply transform to DPC_ACL_025.fits
# Registering TI_ACL_015.fits
# Apply transform to DFI_ACL_015.fits
# Apply transform to DPC_ACL_015.fits
# Registering TI_ACL_005.fits
# Apply transform to DFI_ACL_005.fits
# Apply transform to DPC_ACL_005.fits
# Registering TI_ACL_002.fits
# Apply transform to DFI_ACL_002.fits
# Apply transform to DPC_ACL_002.fits

# %%
img_idx = -1
img_name = name_pattern[0]
#########################
f, ax = plt.subplots(1, 3, figsize=(20, 9))
check_reg =  rocku.composite_images([reg_dict[img_name][0], reg_dict[img_name][img_idx]])

ax[0].imshow(unreg_dict[img_name][img_idx], cmap='gray')
ax[0].set_title('Unregistered image')
ax[0].axis('off')

ax[1].imshow(reg_dict[img_name][img_idx], cmap='gray')
ax[1].set_title('Registered image')
ax[1].axis('off')

ax[2].imshow(check_reg)
ax[2].set_title('Overlay with Reference (reference=green, changed=red)')
ax[2].axis('off');

# %%
img_idx = -1
img_name = name_pattern[1]
#########################
f, ax = plt.subplots(1, 3, figsize=(20, 9))
check_reg = rocku.composite_images([reg_dict[img_name][0], reg_dict[img_name][img_idx]])

ax[0].imshow(unreg_dict[img_name][img_idx], cmap='gray')
ax[0].set_title('Unregistered image')
ax[0].axis('off')

ax[1].imshow(reg_dict[img_name][img_idx], cmap='gray')
ax[1].set_title('Registered image')
ax[1].axis('off')

ax[2].imshow(check_reg)
ax[2].set_title('Overlay with Reference (reference=green, changed=red)')
ax[2].axis('off');
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Save files

# %%
################ change save path for your own
save_to = "/HFIR/CG1D/IPTS-"+ipts+"/shared/analysis/" + sample_name + "_" + trans_algo# + '_redo'
if not os.path.exists(save_to):
    os.mkdir(save_to)
print("Saving to '{}' ...".format(save_to))
for each in name_pattern:
    for i, e_name in tqdm(enumerate(fname_dict_out[each])):
        fname = save_to + "/" + e_name + ".tiff"
        img_pl = Image.fromarray(reg_dict[each][i])
        img_pl.save(fname)
# Out:
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0022nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0030nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0075nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0119nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0163nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0207nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0252nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0296nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0340nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0384nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0429nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0473nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0517nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0561nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0606nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0650nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0694nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0738nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0783nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0827nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0871nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/TI_ACL_0884nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0022nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0030nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0075nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0119nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0163nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0207nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0252nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0296nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0340nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0384nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0429nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0473nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0517nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0561nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0606nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0650nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0694nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0738nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0783nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0827nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0871nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DFI_ACL_0884nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0022nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0030nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0075nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0119nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0163nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0207nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0252nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0296nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0340nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0384nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0429nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0473nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0517nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0561nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0606nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0650nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0694nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0738nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0783nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0827nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0871nm.tiff ...
# Saving to /HFIR/CG1D/IPTS-31969/shared/analysis/2023_09_05_C123_coarse_SCALED_ROTATION/DPC_ACL_0884nm.tiff ...
