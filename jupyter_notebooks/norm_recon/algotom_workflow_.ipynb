# %%
import os
import tomopy
import numpy as np
from imars3d.filters import tilt
import matplotlib.pyplot as plt
import sys
root_folder = os.path.dirname(os.getcwd())
sys.path.append(root_folder)
import utilities as rocku
import dxchange
import algotom.io.loadersaver as losa
import algotom.prep.correction as corr
import algotom.io.converter as conv
import h5py as h5f
import timeit

# %%
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# # Workflow starts here!

# %%
###################### need to change start
ipts="29298"
###################### need to change end

# %% [markdown]
# ## Find CT scan location

# %%
ct_loc = "/HFIR/CG1D/IPTS-"+ipts+"/raw/ct_scans"
# ct_loc = "/HFIR/CG1D/IPTS-"+ipts+"/shared/autoreduce/raw_to_recon"
os.listdir(ct_loc)
# Out:
# ['2022_09_29_sample2',
#  '2022_09_29_sample1',
#  '2022_09_29_sample4',
#  '2022_09_29_sample3']

# %% [markdown]
# ## Find OB location

# %%
ob_loc = "/HFIR/CG1D/IPTS-"+ipts+"/raw/ob"
# ob_loc = "/HFIR/CG1D/IPTS-"+ipts+"/shared/autoreduce/raw_to_recon"
os.listdir(ob_loc)
# Out:
# ['2022_09_29', '2022_09_30']

# %% [markdown]
# ## Find DC location

# %%
dc_loc = "/HFIR/CG1D/IPTS-"+ipts+"/raw/df"
# dc_loc = "/HFIR/CG1D/IPTS-"+ipts+"/shared/autoreduce/raw_to_recon"
os.listdir(dc_loc)
# Out:
# ['2022_09_29']

# %%
###################### need to change start
sample_name = "2022_09_29_sample1"
ct_dir = os.path.join(ct_loc, sample_name)
ob_dir = os.path.join(ob_loc, "2022_09_29")
dc_dir = os.path.join(dc_loc, "2022_09_29")
# ct_dir = "/HFIR/CG1D/IPTS-"+ipts+"/shared/processed_data/raw_to_recon"
# ob_dir = "/HFIR/CG1D/IPTS-"+ipts+"/shared/processed_data/raw_to_recon"
# dc_dir = "/HFIR/CG1D/IPTS-"+ipts+"/shared/processed_data/raw_to_recon"
gamma_diff = 20
end_ang = 359.1 # Will not be used if the CT file names contain angle info
ct_name = "*battery*" # Will not be used if follows the default file structure
ob_name = "*ob*" # Will not be used if follows the default file structure
dc_name = "*dc*" # Will not be used if follows the default file structure
output_hdf5 = "/HFIR/CG1D/IPTS-"+ipts+"/shared/autoreduce/hdf5/" + sample_name + ".h5"
###################### need to change end

# %% [markdown]
# # Load all data files (CT, OB and DC)

# %%
######### CT
proj_raw, ang_deg, ang_rad, proj180_ind, fname_sorted = rocku.load_ct(ct_dir, ang2=end_ang, name=ct_name)
######### OB
ob_raw = rocku.load_ob(ob_dir, name=ob_name)
######### DC
dc_raw = rocku.load_dc(dc_dir, name=dc_name)
# Out:
# Found index of 180 degree projections:  391
# Loading CT projections...
# Loading CT projections...Done!
# Shape: (783, 2048, 2048)
# 5 files to be loaded:
# ['20220929_OB_0020_0807.tiff', '20220929_OB_0020_0808.tiff', '20220929_OB_0020_0809.tiff', '20220929_OB_0020_0810.tiff', '20220929_OB_0020_0811.tiff']
# Loading Open Beam (OB)...
# Loading Open Beam (OB)...Done!
# Shape: (5, 2048, 2048)
# 5 files to be loaded:
# ['20220929_DF_0020_0802.tiff', '20220929_DF_0020_0803.tiff', '20220929_DF_0020_0804.tiff', '20220929_DF_0020_0805.tiff', '20220929_DF_0020_0806.tiff']
# Loading Dark Current (DC)...
# Loading Dark Current (DC)...Done!
# Shape: (5, 2048, 2048)

# %% [markdown]
# # Visual verification of loaded files

# %%
proj_min = np.min(proj_raw, axis=0)
ob_min = np.min(ob_raw, axis=0)
dc_max = np.max(dc_raw, axis=0)
plt.imshow(proj_min)
plt.colorbar()
plt.show()
plt.imshow(ob_min)
plt.colorbar()
plt.show()
plt.imshow(dc_max)
plt.colorbar()
plt.show()

# %% [markdown]
# # Define/crop ROI

# %%
###################### need to change start
crop = True
crop_left = 750
crop_right = 1500
crop_top = 100
crop_bottom = 1950
###################### need to change end
if crop:
    proj_crop = proj_raw[:, crop_top:crop_bottom, crop_left:crop_right]
    ob_crop = ob_raw[:, crop_top:crop_bottom, crop_left:crop_right]
    dc_crop = dc_raw[:, crop_top:crop_bottom, crop_left:crop_right]
else:
    proj_crop = proj_raw[:]
    ob_crop = ob_raw[:]
    dc_crop = dc_raw[:]

# %%
proj_crop_min = proj_min[crop_top:crop_bottom, crop_left:crop_right]
print("Recon ROI:")
plt.imshow(proj_crop_min)
plt.colorbar()
plt.show()
# Out:
# Recon ROI:

# %% [markdown]
# # Remove Outliers

# %%
proj_crop = tomopy.misc.corr.remove_outlier(proj_crop, gamma_diff).astype(np.ushort)
ob_crop = tomopy.misc.corr.remove_outlier(ob_crop, gamma_diff).astype(np.ushort)
dc_crop = tomopy.misc.corr.remove_outlier(dc_crop, gamma_diff).astype(np.ushort)

# %% [markdown]
# # Normalization

# %%
proj_norm, ob_med, dc_med = rocku.normalize(proj_crop, ob_crop, dc_crop)
print(proj_norm.dtype)
print(proj_norm.shape)
plt.imshow(proj_norm[0], vmin=0, vmax=1)
plt.colorbar()
plt.show()
# Out:
# OB stack combined by median.
# DC stack combined by median.
# Normalizing...
# Normalization Done!
# float32
# (783, 1850, 750)

# %% [markdown]
# # Beam fluctuation correction (optional)

# %%
###################### need to change start
bg_left = 5
bg_right = 80
bg_top = 500
bg_bottom = 1100
###################### need to change end
bg_stack = proj_norm[:, bg_top:bg_bottom, bg_left:bg_right]
bg_min = np.min(bg_stack, axis=0)
print("Beam fluctuation ROI:")
plt.imshow(bg_min, vmin=0, vmax=1)
plt.colorbar()
plt.show()
# Out:
# Beam fluctuation ROI:

# %%
proj_norm = tomopy.prep.normalize.normalize_roi(proj_norm, roi= [bg_top, bg_left, bg_bottom, bg_right])
plt.imshow(proj_norm[0], vmin=0, vmax=1)
plt.colorbar()
plt.show()

# %%
t0 = timeit.default_timer()
proj_align_seq = tomopy.align_seq(proj_norm, ang_rad)
t1 = timeit.default_timer()
print("Time cost {} min".format((t1-t0)/60)
# Out:
# iter=0, err=0.0
# iter=1, err=0.0
# iter=2, err=0.0
# iter=3, err=0.0
# iter=4, err=0.0
# iter=5, err=0.0
# iter=6, err=0.0
# iter=7, err=0.0
# iter=8, err=0.0
# iter=9, err=0.0
# Time cost 17640.6580139508

# %%
print("Align seq:")
plt.imshow(proj_align_seq[0][:, 700, :], vmin=0, vmax=1)
plt.colorbar()
plt.show()
# Out:
# Align seq:

# %%
print("Before ring removal:")
plt.imshow(proj_norm[:, 600, :], vmin=0, vmax=1)
plt.colorbar()
plt.show()
# Out:
# Before ring removal:

# %% [markdown]
# # Export to HDF5

# %%
with h5f.File(output_hdf5, mode='a') as f:
#     f.create_group('tomo/raw')
#     f.create_dataset('tomo/raw/proj', data=proj_crop)
#     f.create_dataset('tomo/raw/ob', data=ob_med)
#     f.create_dataset('tomo/raw/dc', data=dc_med)
    f.create_group('tomo/proj')
    f.create_dataset('tomo/proj/proj_norm', data=proj_norm)
    f.create_dataset('tomo/proj/proj_rmv', data=proj_rmv, dtype=np.float32)
    f.create_dataset('tomo/proj/ob_fake', data=np.ones((proj_norm.shape[1], proj_norm.shape[2]), dtype=np.uint8))
    f.create_dataset('tomo/proj/dc_fake', data=np.zeros((proj_norm.shape[1], proj_norm.shape[2]), dtype=np.uint8))
    f.create_group('tomo/sino')
    f.create_dataset('tomo/sino/sino_norm', data=np.moveaxis(proj_norm, 1, 0))
    f.create_dataset('tomo/sino/sino_rmv', data=np.moveaxis(proj_rmv, 1, 0), dtype=np.float32)
    f.create_group('tomo/meta')
    f.create_dataset('tomo/meta/ang_deg', data=ang_deg, dtype=np.float32)
    f.create_dataset('tomo/meta/ang_rad', data=ang_rad, dtype=np.float64)
    f.create_dataset('tomo/meta/proj180_idx', data=(proj180_ind,), dtype=np.uint16)
    f.create_dataset('tomo/meta/ring_rmv', data=('bm3d',))
    f.create_dataset('tomo/meta/fname', data=fname_sorted)

# %%
proj_norm.dtype
# Out:
# dtype('float32')

# %%
losa.get_hdf_tree(output_hdf5)
# Out:
# │
# ├── config
# │   │
# │   ├── ang_deg (783,)
# │   ├── ang_rad (783,)
# │   ├── fname (783,)
# │   └── proj180_idx ()
# ├── tomo_norm
# │   │
# │   ├── dc (1850, 750)
# │   ├── ob (1850, 750)
# │   └── proj (783, 1850, 750)
# └── tomo_raw
#     │
#     ├── dc (1850, 750)
#     ├── ob (1850, 750)
#     └── proj (783, 1850, 750)
# deque(['│',
#        '├── config',
#        '│   │',
#        '│   ├── ang_deg (783,)',
#        '│   ├── ang_rad (783,)',
#        '│   ├── fname (783,)',
#        '│   └── proj180_idx ()',
#        '├── tomo_norm',
#        '│   │',
#        '│   ├── dc (1850, 750)',
#        '│   ├── ob (1850, 750)',
#        '│   └── proj (783, 1850, 750)',
#        '└── tomo_raw',
#        '    │',
#        '    ├── dc (1850, 750)',
#        '    ├── ob (1850, 750)',
#        '    └── proj (783, 1850, 750)'])

# %%
keys, shapes, types = losa.find_hdf_key(output_hdf5, "ang")
for i in range(len(keys)):
    print(i," Key: {0} | Shape: {1} | Type: {2} ".format(keys[i], shapes[i], types[i]))
# Out:
# 0  Key: config/ang_deg | Shape: (1000,) | Type: float32
# 1  Key: config/ang_rad | Shape: (1000,) | Type: float64
# 2  Key: /config/ang_deg | Shape: (1000,) | Type: float32
# 3  Key: /config/ang_rad | Shape: (1000,) | Type: float64

# %%
name_list = losa.load_hdf(output_hdf5, key_path='config/fname')

# %% [markdown]
# # Ring Artifact Removal

# %%
# proj_rmv = rocku.remove_ring(proj_norm, algorithm="Vo")
############## bm3d, slightly better, but slow
proj_rmv = rocku.remove_ring(proj_norm, algorithm="bm3d")
# Out:
# Median filtering, iteration 0
# Median filtering, iteration 1
# Median filtering, iteration 2
# Denoising sinogram 0
# k: 4
# k: 3
# k:
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1701
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1702
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1703
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1704
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1705
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1706
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1707
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1708
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1709
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1710
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1711
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1712
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1713
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1714
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1715
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1716
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1717
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1718
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1719
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1720
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1721
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1722
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1723
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1724
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1725
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1726
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1727
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1728
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1729
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1730
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1731
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1732
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1733
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1734
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1735
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1736
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1737
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1738
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1739
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1740
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1741
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1742
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1743
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1744
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1745
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1746
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1747
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1748
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1749
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1750
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1751
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1752
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1753
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1754
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1755
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1756
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1757
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1758
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1759
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1760
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1761
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1762
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1763
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1764
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1765
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1766
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1767
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1768
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1769
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1770
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1771
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1772
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1773
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1774
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1775
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1776
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1777
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1778
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1779
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1780
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1781
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1782
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1783
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1784
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1785
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1786
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1787
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1788
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1789
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1790
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1791
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1792
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1793
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1794
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1795
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1796
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1797
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1798
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1799
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1800
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1801
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1802
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1803
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1804
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1805
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1806
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1807
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1808
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1809
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1810
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1811
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1812
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1813
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1814
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1815
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1816
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1817
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1818
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1819
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1820
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1821
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1822
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1823
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1824
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1825
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1826
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1827
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1828
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1829
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1830
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1831
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1832
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1833
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1834
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1835
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1836
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1837
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1838
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1839
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1840
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1841
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1842
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1843
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1844
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1845
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1846
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1847
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1848
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0
# Denoising sinogram 1849
# k: 4
# k: 3
# k: 2
# k: 1
# k: 0

# %%
proj_rmv_vo = rocku.remove_ring(proj_norm, algorithm="Vo")
############## bm3d, slightly better, but slow
# proj_rmv = rocku.remove_ring(proj_norm, algorithm="bm3d")

# %%
slice_num = 600
print("Difference:")
plt.imshow(proj_rmv_vo[:, slice_num, :].astype(np.float32)-proj_norm[:, slice_num, :])
plt.colorbar()
plt.show()
# Out:
# Difference:

# %%
slice_num = 600
plt.imshow(proj_rmv[:, slice_num, :]-proj_norm[:, slice_num, :])
plt.colorbar()
plt.show()

# %% [markdown]
# # Minus log conversion

# %%
proj_mlog = tomopy.minus_log(proj_rmv)
plt.imshow(proj_mlog[0])
plt.colorbar()
plt.show()

# %% [markdown]
# # Remove Outliers again (optional)

# %%
proj_mlog = tomopy.remove_outlier(proj_mlog, gamma_diff)
proj_mlog = tomopy.remove_nan(proj_mlog)
# proj_mlog = tomopy.remove_neg(proj_mlog)
plt.imshow(proj_mlog[0])
plt.colorbar()
plt.show()

# %% [markdown]
# # Find and correct tilt

# %%
###################### need to change start
tt_xmin = 200
tt_xmax = 800
tt_ymin = 200
tt_ymax = 900
###################### need to change start
tt_roi = [tt_ymin, tt_xmin, tt_ymax, tt_xmax] # 
tt_0deg = proj_mlog[0, tt_roi[0]:tt_roi[2], tt_roi[1]:tt_roi[3]]
tt_180deg = proj_mlog[proj180_ind, tt_roi[0]:tt_roi[2], tt_roi[1]:tt_roi[3]]
print("Tilt correction ROI at 0 degree:")
plt.imshow(tt_0deg)
plt.colorbar()
plt.show()
print("Tilt correction ROI at 180 degree:")
plt.imshow(tt_180deg)
plt.colorbar()
plt.show()
# Out:
# Tilt correction ROI at 0 degree:
# Tilt correction ROI at 180 degree:

# %%
print("Finding the tilt angle...")
tilt_ang = tilt.calculate_tilt(image0=tt_0deg, image180=tt_180deg)
print("Found the tilt angle: ", tilt_ang.x)
# Out:
# Finding the tilt angle...
# Found the tilt angle:  0.07377669291773652

# %%
proj_mlog_tilt = tilt.apply_tilt_correction(proj_mlog, tilt_ang.x)
# proj_mlog_tilt = tilt.apply_tilt_correction(proj_mlog, 0.112)

# proj_tilt = tilt.apply_tilt_correction(proj_rmv, 0.112)
# Out:
# Applying tilt corr: 100%|██████████████████| 1000/1000 [00:09<00:00, 104.32it/s]

# %%
print("Projection at 0 degree:")
plt.imshow(proj_mlog[0])# vmin=0, vmax=1)
plt.colorbar()
plt.show()
print("Projection at 180 degree (flipped):")
plt.imshow(np.fliplr(proj_mlog[proj180_ind]))# vmin=0, vmax=1)
plt.colorbar()
plt.show()
# Out:
# Projection at 0 degree:
# Projection at 180 degree (flipped):

# %% [markdown]
# # Find Center of Rotation

# %%
rot_center = tomopy.find_center_pc(np.squeeze(proj_mlog[0,:,:]), np.squeeze(proj_mlog[proj180_ind,:,:]), tol=0.5)
print('Estimated center of rotation:', rot_center) # 389.5
# Out:
# Estimated center of rotation: 513.5

# %%
rot_center = tomopy.find_center_pc(np.squeeze(proj_rmv[0,:,:]), np.squeeze(proj_rmv[proj180_ind,:,:]), tol=0.5)
print('Estimated center of rotation:', rot_center) # 389.5
# Out:
# Estimated center of rotation: 517.0

# %% [markdown]
# # Reconstruction

# %%
########## tomopy
recon = rocku.recon(proj_mlog_tilt, ang_rad, rot_center=rot_center, algorithm='gridrec')
# ########## svMBIR
# recon = recon(proj_tilt, theta, rot_center=rot_center, algorithm='svMBIR')
plt.imshow(recon[600, :, :], vmax=0.004, vmin=0)
plt.colorbar()
plt.show()

# %%
plt.imshow(recon[400, :, :])
plt.colorbar()
plt.show()

# %%
pix_um = 42.7 #um
pix_cm = pix_um/10000
recon_cm = recon/pix_cm

# %% [markdown]
# # Export recon files

# %%
################ change save path for your own
# save_to = "/HFIR/CG1D/IPTS-"+ipts+"/shared/autoreduce/rockit/" + sample_name# + "_vo"
save_to = "/HFIR/CG1D/IPTS-"+ipts+"/shared/processed_data/rockit/" + sample_name + "_vo"
dxchange.write_tiff_stack(recon_cm, fname=save_to + "/recon", overwrite=True, digit=4)

# %% [markdown]
# # Export proj files (optional)

# %%
if proj_rmv.dtype == np.float32:
    proj_output = proj_rmv[:]
else:  
    proj_output = proj_rmv.astype(np.float32)
# proj_output = proj_norm.astype(np.float32)
# proj_output = np.exp(-1 * proj_output) # convert back to transmission
ob_output = np.ones((proj_output.shape[1],proj_output.shape[2]), dtype=proj_output.dtype)
dc_output = np.zeros((proj_output.shape[1],proj_output.shape[2]), dtype=proj_output.dtype)
plt.imshow(proj_output[0], vmin=0, vmax=1)
plt.colorbar()
plt.show()
plt.imshow(ob_output, vmin=0, vmax=1)
plt.colorbar()
plt.show()
plt.imshow(dc_output, vmin=0, vmax=1)
plt.colorbar()
plt.show()

# %%
################ change save path for your own
save_to = "/HFIR/CG1D/IPTS-"+ipts+"/shared/autoreduce/raw_to_recon/" + sample_name + "_norm"
dxchange.write_tiff_stack(proj_output, fname=save_to + "/raw", overwrite=True, digit=4)
dxchange.write_tiff(ob_output, fname=save_to + '/ob_0000', overwrite=True)
dxchange.write_tiff(dc_output, fname=save_to + '/dc_0000', overwrite=True)
