# %%
import os
import numpy as np
import sys
import pandas as pd
root_folder = os.path.dirname(os.getcwd())
sys.path.append(root_folder)

# %%
# %matplotlib notebook
# %matplotlib inline

# %%
###################### need to change start
ipts="26032"
###################### need to change end

# %%
scan_loc = "/HFIR/CG1D/IPTS-"+ipts+"/raw/radiographs"
# ct_loc = "/HFIR/CG1D/IPTS-"+ipts+"/shared/autoreduce/rockit"
# ct_loc = "/HFIR/CG1D/IPTS-"+ipts+"/shared/autoreduce/raw_to_recon"
scan_list = os.listdir(scan_loc)
sorted(scan_list, reverse=True)
# Out:
# ['test_python_TTL',
#  'test',
#  '2023_05_28_powder',
#  '2023_05_26_PMMA',
#  '2023_05_26_OB_G2_flipped',
#  '2023_05_25_stability',
#  '2023_05_25_PMMA',
#  '2023_05_25_OB',
#  '2023_05_24_stability',
#  '2023_05_24_absorption',
#  '2022_04_22_stability',
#  '2022_04_06_TL_stability',
#  '2022_04_06_TL_nGI_scan1_no_delay',
#  '2022_04_06_TL_nGI_scan1',
#  '2022_04_06_TL_nGI_G1_Roll_fine',
#  '2022_04_05_TL_nGI_stability',
#  '2022_04_05_TL_nGI_alignment',
#  '2022_04_05_TL_nGI_G1_Roll',
#  '2022_04_05_TL_nGI_G0_stepping',
#  '2022_04_05_TL_nGI_G0_Roll',
#  '2021_10_04_stability_newCCD',
#  '2021_09_02_stability_NoGratings_5mm_graphite',
#  '2021_09_02_stability_NoGratings_4mm_Al2O3',
#  '2021_09_01_stability_NoGratings_16mm_PinHole',
#  '2021_08_31_stability_NoGratings',
#  '2021_08_30_stability_G1in_PowerOff',
#  '2021_08_29_stability_G0in_PowerOff',
#  '2021_08_28_stability_G0in_PowerOn',
#  '2021_08_27_stability_G0in_PowerOn',
#  '2021_06_01_momo',
#  '2021_06_01_OB_mono_60s',
# ...

# %%
scan_name = "2023_05_26_PMMA"
scan_dir = os.path.join(scan_loc, scan_name)
file_list = os.listdir(scan_dir)
file_list = sorted(file_list, reverse=False)
file_list
# Out:
# ['20230527_ACL01_171_0030_0001.tiff',
#  '20230527_ACL01_171_0030_0002.tiff',
#  '20230527_ACL01_171_0030_0003.tiff',
#  '20230527_ACL01_171_0030_0004.tiff',
#  '20230527_ACL01_171_0030_0005.tiff',
#  '20230527_ACL01_171_0030_0006.tiff',
#  '20230527_ACL01_171_0030_0007.tiff',
#  '20230527_ACL01_171_0030_0008.tiff',
#  '20230527_ACL01_171_0030_0009.tiff',
#  '20230527_ACL01_171_0030_0010.tiff',
#  '20230527_ACL01_171_0030_0011.tiff',
#  '20230527_ACL01_171_0030_0012.tiff',
#  '20230527_ACL01_171_0030_0013.tiff',
#  '20230527_ACL01_171_0030_0014.tiff',
#  '20230527_ACL01_171_0030_0015.tiff',
#  '20230527_ACL01_171_0030_0016.tiff',
#  '20230527_ACL01_171_0030_0017.tiff',
#  '20230527_ACL01_171_0030_0018.tiff',
#  '20230527_ACL01_171_0030_0019.tiff',
#  '20230527_ACL01_171_0030_0020.tiff',
#  '20230527_ACL01_171_0030_0021.tiff',
#  '20230527_ACL01_171_0030_0022.tiff',
#  '20230527_ACL01_171_0030_0023.tiff',
#  '20230527_ACL01_171_0030_0024.tiff',
#  '20230527_ACL01_171_0030_0025.tiff',
# ...

# %%
os.listdir("/HFIR/CG1D/IPTS-26647/shared/notes_photos")
# Out:
# ['Angel_batch_zyx_DOE.xls',
#  'Angel_batch_zyx_test.xls',
#  'nGI_multiACL_temp.xlsx',
#  '2022_05_04_Al_blocks_angel_excel_test.xls',
#  '2023_05_28_multiACL.xlsx',
#  'Angel_batch_zyx_test0.xls',
#  '.~lock.Angel_batch_monalisa_angles.xls#',
#  'Angel_batch_DOE_angles.xls',
#  '.~lock.Angel_batch_DOE_angles.xls#',
#  '.~lock.2023_05_28_multiACL.xlsx#',
#  '2022_04_29_TI64_CT_angel_excel.xls',
#  'Angel_batch_monalisa_angles_180.xls',
#  '2022_04_29_DOE_CT_angel_excel.xls',
#  '2022_05_03_samples_angel_excel.xls',
#  'Angel_batch_monalisa_angles.xls',
#  '2022_05_04_Al_blocks_angel_excel.xls']

# %%
df_ = pd.read_excel("/HFIR/CG1D/IPTS-26647/shared/notes_photos/nGI_multiACL_temp.xlsx", engine='xlrd')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/rockit/lib/python3.10/site-packages/pandas/compat/_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File ~/anaconda3/envs/rockit/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ...
