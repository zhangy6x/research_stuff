# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path_to_file = '/Users/y9z/Documents/data/data_part1.dat'

# %%
col_name_1 = ['E_eV', 'I_angstrom', 'f(E)', 's(E)', 'f(I)', 's(I)']
col_name_1
# Out:
# ['E_eV', 'I_angstrom', 'f(E)', 's(E)', 'f(I)', 's(I)']

# %%
df1.columns = col_name_1

# %%
df1.to_clipboard()

# %%
col_name_2 = ['t_us', 'E_eV', 'f', 's']
col_name_2
# Out:
# ['t_us', 'E_eV', 'f', 's']

# %%
df2.columns = col_name_2
df2.to_clipboard()

# %%
df1
# Out:
#                E_eV  I_angstrom          f(E)  s(E)          f(I)  s(I)
# 0          0.000010   90.441000  4.305100e+11   0.0  9.520200e+04   0.0
# 1          0.000011   85.382000  5.442500e+11   0.0  1.430400e+05   0.0
# 2          0.000013   80.606000  8.525500e+11   0.0  2.663100e+05   0.0
# 3          0.000014   76.097000  7.631300e+11   0.0  2.833100e+05   0.0
# 4          0.000016   71.840000  9.077700e+11   0.0  4.005400e+05   0.0
# 5          0.000018   67.821000  1.148000e+12   0.0  6.020300e+05   0.0
# 6          0.000020   64.027000  1.229800e+12   0.0  7.664700e+05   0.0
# 7          0.000022   60.446000  1.198600e+12   0.0  8.878200e+05   0.0
# 8          0.000025   57.064000  1.891500e+12   0.0  1.665200e+06   0.0
# 9          0.000028   53.872000  1.575900e+12   0.0  1.648900e+06   0.0
# 10         0.000032   50.859000  1.990000e+12   0.0  2.474700e+06   0.0
# 11         0.000035   48.014000  2.571700e+12   0.0  3.800900e+06   0.0
# ...

# %%
p = np.genfromtxt('/Users/y9z/Documents/data/source_section_1.dat')

# %%
q = np.genfromtxt('/Users/y9z/Documents/data/source_section_2.dat')

# %%
p
# Out:
# array([[  1.00000000e-05,   9.04410000e+01,   4.30510000e+11,
#           0.00000000e+00,   9.52020000e+04,   0.00000000e+00],
#        [  1.12200000e-05,   8.53820000e+01,   5.44250000e+11,
#           0.00000000e+00,   1.43040000e+05,   0.00000000e+00],
#        [  1.25890000e-05,   8.06060000e+01,   8.52550000e+11,
#           0.00000000e+00,   2.66310000e+05,   0.00000000e+00],
#        ...,
#        [  7.94330000e+05,   3.20900000e-04,   4.12670000e+03,
#           0.00000000e+00,   2.04300000e+13,   0.00000000e+00],
#        [  8.91250000e+05,   3.02950000e-04,   2.49770000e+03,
#           0.00000000e+00,   1.46960000e+13,   0.00000000e+00],
#        [  1.00000000e+06,   2.86000000e-04,   1.83880000e+03,
#           0.00000000e+00,   1.28590000e+13,   0.00000000e+00]])

# %%
q
# Out:
# array([[  5.00000000e-02,   1.00000000e-05,   0.00000000e+00,
#           0.00000000e+00],
#        [  1.03300000e-01,   1.00000000e-05,   0.00000000e+00,
#           0.00000000e+00],
#        [  1.10130000e-01,   1.00000000e-05,   0.00000000e+00,
#           0.00000000e+00],
#        ...,
#        [  5.50000000e+04,   1.00000000e+06,   0.00000000e+00,
#           0.00000000e+00],
#        [  5.50000000e+05,   1.00000000e+06,   0.00000000e+00,
#           0.00000000e+00],
#        [  5.50000000e+06,   1.00000000e+06,   0.00000000e+00,
#           0.00000000e+00]])

# %%
plt.plot(df1[0], df1[2])

# %%
pp = p.T
df1 = pd.DataFrame()
for i, col in enumerate(pp):
    df1[i] = col
df1
# Out:
#                   0          1             2    3             4    5
# 0          0.000010  90.441000  4.305100e+11  0.0  9.520200e+04  0.0
# 1          0.000011  85.382000  5.442500e+11  0.0  1.430400e+05  0.0
# 2          0.000013  80.606000  8.525500e+11  0.0  2.663100e+05  0.0
# 3          0.000014  76.097000  7.631300e+11  0.0  2.833100e+05  0.0
# 4          0.000016  71.840000  9.077700e+11  0.0  4.005400e+05  0.0
# 5          0.000018  67.821000  1.148000e+12  0.0  6.020300e+05  0.0
# 6          0.000020  64.027000  1.229800e+12  0.0  7.664700e+05  0.0
# 7          0.000022  60.446000  1.198600e+12  0.0  8.878200e+05  0.0
# 8          0.000025  57.064000  1.891500e+12  0.0  1.665200e+06  0.0
# 9          0.000028  53.872000  1.575900e+12  0.0  1.648900e+06  0.0
# 10         0.000032  50.859000  1.990000e+12  0.0  2.474700e+06  0.0
# 11         0.000035  48.014000  2.571700e+12  0.0  3.800900e+06  0.0
# 12         0.000040  45.328000  2.771400e+12  0.0  4.868100e+06  0.0
# ...

# %%
qq = q.T
df2 = pd.DataFrame()
for i, col in enumerate(qq):
    df2[i] = col
df2
# Out:
#                   0              1    2    3
# 0      5.000000e-02        0.00001  0.0  0.0
# 1      1.033000e-01        0.00001  0.0  0.0
# 2      1.101300e-01        0.00001  0.0  0.0
# 3      1.174000e-01        0.00001  0.0  0.0
# 4      1.251500e-01        0.00001  0.0  0.0
# 5      1.334200e-01        0.00001  0.0  0.0
# 6      1.422300e-01        0.00001  0.0  0.0
# 7      1.516300e-01        0.00001  0.0  0.0
# 8      1.616400e-01        0.00001  0.0  0.0
# 9      1.723200e-01        0.00001  0.0  0.0
# 10     1.837000e-01        0.00001  0.0  0.0
# 11     1.958300e-01        0.00001  0.0  0.0
# 12     2.087700e-01        0.00001  0.0  0.0
# 13     2.225600e-01        0.00001  0.0  0.0
# 14     2.372600e-01        0.00001  0.0  0.0
# 15     2.529300e-01        0.00001  0.0  0.0
# 16     2.696400e-01        0.00001  0.0  0.0
# 17     2.874500e-01        0.00001  0.0  0.0
# 18     3.064300e-01        0.00001  0.0  0.0
# 19     3.266700e-01        0.00001  0.0  0.0
# ...
