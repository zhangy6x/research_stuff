# %%
from ImagingReso.resonance import Resonance
import pprint
import numpy as np
# %matplotlib inline

# %%
# Global parameters
energy_min = 1
energy_max = 1000
energy_step = 1

# %%
o_reso = Resonance(energy_min=energy_min,
                   energy_max=energy_max,
                   energy_step=energy_step,
                   database='ENDF_VII')

# %%
layer_1 = 'Ti'
thickness_1 = 1  # mm
# density_1 = 0.223  # g/cm3
layer_2 = 'Fe'
thickness_2 = 1  # mm
# density_2 = 0.243  # g/cm3
layer_3 = 'Zr'
thickness_3 = 1  # mm
# density_3 = 0.223  # g/cm3
layer_4 = 'V'
thickness_4 = 0.01  # mm
# density_4 = 0.223  # g/cm3
layer_5 = 'Nb'
thickness_5 = 0.01  # mm
# density_5 = 0.223  # g/cm3
layer_6 = 'Mo'
thickness_6 = 0.01  # mm
# density_6 = 0.223  # g/cm3

layer_7 = 'SiO2'
thickness_7 = 0.01  # mm
# density_6 = 0.223  # g/cm3

layer_8 = 'Al2O3'
thickness_8 = 0.01  # mm
# density_6 = 0.223  # g/cm3

# %%
o_reso.add_layer(formula=layer_1, thickness=thickness_1)
o_reso.add_layer(formula=layer_2, thickness=thickness_2)
o_reso.add_layer(formula=layer_3, thickness=thickness_3)
o_reso.add_layer(formula=layer_4, thickness=thickness_4)
o_reso.add_layer(formula=layer_5, thickness=thickness_5)
o_reso.add_layer(formula=layer_6, thickness=thickness_6)
o_reso.add_layer(formula=layer_7, thickness=thickness_7)
o_reso.add_layer(formula=layer_8, thickness=thickness_8)

# %%
pprint.pprint(o_reso.stack)
# Out:
# {'Al2O3': {'Al': {'density': {'units': 'g/cm3', 'value': 2.6989},
#                   'isotopes': {'density': {'units': 'g/cm3',
#                                            'value': [2.6989000440121687]},
#                                'file_names': ['Al-27.csv'],
#                                'isotopic_ratio': [1.0],
#                                'list': ['27-Al'],
#                                'mass': {'units': 'g/mol',
#                                         'value': [26.98153844]}},
#                   'molar_mass': {'units': 'g/mol', 'value': 26.981538}},
#            'O': {'density': {'units': 'g/cm3', 'value': 1.14},
#                  'isotopes': {'density': {'units': 'g/cm3',
#                                           'value': [1.1396804048398064,
#                                                     1.2112335406327737]},
#                               'file_names': ['O-16.csv', 'O-17.csv'],
#                               'isotopic_ratio': [0.9975700000000001,
#                                                  0.00037999999999999997],
#                               'list': ['16-O', '17-O'],
#                               'mass': {'units': 'g/mol',
#                                        'value': [15.9949146221, 16.9991315]}},
#                  'molar_mass': {'units': 'g/mol', 'value': 15.9994}},
#            'atoms_per_cm3': {'Al': 2.083223581817654e+22,
#                              'O': 3.1248353727264808e+22},
#            'density': {'units': 'g/cm3', 'value': 1.76356},
#            'elements': ['Al', 'O'],
#            'stoichiometric_ratio': [2, 3],
#            'thickness': {'units': 'mm', 'value': 0.01}},
#  'Fe': {'Fe': {'density': {'units': 'g/cm3', 'value': 7.874},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [7.6053456340800425,
#                                                   7.886681602567821,
#                                                   8.027743385509893,
#                                                   8.168442128337363]},
#                             'file_names': ['Fe-54.csv',
#                                            'Fe-56.csv',
#                                            'Fe-57.csv',
#                                            'Fe-58.csv'],
#                             'isotopic_ratio': [0.058449999999999995,
#                                                0.91754,
#                                                0.02119,
#                                                0.0028199999999999996],
#                             'list': ['54-Fe', '56-Fe', '57-Fe', '58-Fe'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [53.9396148,
#                                                55.9349421,
#                                                56.9353987,
#                                                57.9332805]}},
#                'molar_mass': {'units': 'g/mol', 'value': 55.845}},
#         'atoms_per_cm3': {'Fe': 8.4910622451460282e+22},
#         'density': {'units': 'g/cm3', 'value': 7.8739999999999997},
#         'elements': ['Fe'],
#         'stoichiometric_ratio': [1],
#         'thickness': {'units': 'mm', 'value': 1}},
#  'Mo': {'Mo': {'density': {'units': 'g/cm3', 'value': 10.22},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [10.642635135918283,
#                                                   9.790364792578695,
#                                                   10.003231136877217,
#                                                   10.109836357410883,
#                                                   10.216237422951844,
#                                                   10.3229053014384,
#                                                   10.429364891765687,
#                                                   10.536135215259538]},
#                             'file_names': ['Mo-100.csv',
#                                            'Mo-92.csv',
#                                            'Mo-94.csv',
#                                            'Mo-95.csv',
#                                            'Mo-96.csv',
#                                            'Mo-97.csv',
#                                            'Mo-98.csv',
#                                            'Mo-99.csv'],
#                             'isotopic_ratio': [0.09630000000000001,
#                                                0.1484,
#                                                0.0925,
#                                                0.1592,
#                                                0.1668,
#                                                0.0955,
#                                                0.2413,
#                                                0.0],
#                             'list': ['100-Mo',
#                                      '92-Mo',
#                                      '94-Mo',
#                                      '95-Mo',
#                                      '96-Mo',
#                                      '97-Mo',
#                                      '98-Mo',
#                                      '99-Mo'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [99.907477,
#                                                91.90681,
#                                                93.9050876,
#                                                94.9058415,
#                                                95.9046789,
#                                                96.906021,
#                                                97.9054078,
#                                                98.9077116]}},
#                'molar_mass': {'units': 'g/mol', 'value': 95.94}},
#         'atoms_per_cm3': {'Mo': 6.4150802124807179e+22},
#         'density': {'units': 'g/cm3', 'value': 10.220000000000001},
#         'elements': ['Mo'],
#         'stoichiometric_ratio': [1],
#         'thickness': {'units': 'mm', 'value': 0.01}},
#  'Nb': {'Nb': {'density': {'units': 'g/cm3', 'value': 8.57},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [8.569999769391512,
#                                                   8.662326737894643,
#                                                   8.75452878116659]},
#                             'file_names': ['Nb-93.csv',
#                                            'Nb-94.csv',
#                                            'Nb-95.csv'],
#                             'isotopic_ratio': [1.0, 0.0, 0.0],
#                             'list': ['93-Nb', '94-Nb', '95-Nb'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [92.9063775,
#                                                93.9072835,
#                                                94.9068352]}},
#                'molar_mass': {'units': 'g/mol', 'value': 92.90638}},
#         'atoms_per_cm3': {'Nb': 5.5550272375793782e+22},
#         'density': {'units': 'g/cm3', 'value': 8.5700000000000003},
#         'elements': ['Nb'],
#         'stoichiometric_ratio': [1],
#         'thickness': {'units': 'mm', 'value': 0.01}},
#  'SiO2': {'O': {'density': {'units': 'g/cm3', 'value': 1.14},
#                 'isotopes': {'density': {'units': 'g/cm3',
#                                          'value': [1.1396804048398064,
#                                                    1.2112335406327737]},
#                              'file_names': ['O-16.csv', 'O-17.csv'],
#                              'isotopic_ratio': [0.9975700000000001,
#                                                 0.00037999999999999997],
#                              'list': ['16-O', '17-O'],
#                              'mass': {'units': 'g/mol',
#                                       'value': [15.9949146221, 16.9991315]}},
#                 'molar_mass': {'units': 'g/mol', 'value': 15.9994}},
#           'Si': {'density': {'units': 'g/cm3', 'value': 2.33},
#                  'isotopes': {'density': {'units': 'g/cm3',
#                                           'value': [2.320992641084937,
#                                                     2.4039177759911703,
#                                                     2.4866527073614497]},
#                               'file_names': ['Si-28.csv',
#                                              'Si-29.csv',
#                                              'Si-30.csv'],
#                               'isotopic_ratio': [0.9222969999999999,
#                                                  0.046832000000000006,
#                                                  0.030872],
#                               'list': ['28-Si', '29-Si', '30-Si'],
#                               'mass': {'units': 'g/mol',
#                                        'value': [27.9769265327,
#                                                  28.97649472,
#                                                  29.97377022]}},
#                  'molar_mass': {'units': 'g/mol', 'value': 28.0855}},
#           'atoms_per_cm3': {'O': 3.0803464854956564e+22,
#                             'Si': 1.5401732427478282e+22},
#           'density': {'units': 'g/cm3', 'value': 1.5366666666666666},
#           'elements': ['Si', 'O'],
#           'stoichiometric_ratio': [1, 2],
#           'thickness': {'units': 'mm', 'value': 0.01}},
#  'Ti': {'Ti': {'density': {'units': 'g/cm3', 'value': 4.54},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [4.358429354879145,
#                                                   4.453193382748031,
#                                                   4.547677519669084,
#                                                   4.642516419077861,
#                                                   4.737070552447406]},
#                             'file_names': ['Ti-46.csv',
#                                            'Ti-47.csv',
#                                            'Ti-48.csv',
#                                            'Ti-49.csv',
#                                            'Ti-50.csv'],
#                             'isotopic_ratio': [0.0825,
#                                                0.07440000000000001,
#                                                0.7372,
#                                                0.0541,
#                                                0.0518],
#                             'list': ['46-Ti',
#                                      '47-Ti',
#                                      '48-Ti',
#                                      '49-Ti',
#                                      '50-Ti'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [45.9526295,
#                                                46.9517638,
#                                                47.9479471,
#                                                48.9478708,
#                                                49.9447921]}},
#                'molar_mass': {'units': 'g/mol', 'value': 47.867}},
#         'atoms_per_cm3': {'Ti': 5.7117679175172878e+22},
#         'density': {'units': 'g/cm3', 'value': 4.54},
#         'elements': ['Ti'],
#         'stoichiometric_ratio': [1],
#         'thickness': {'units': 'mm', 'value': 1}},
#  'V': {'V': {'density': {'units': 'g/cm3', 'value': 6.11},
#              'isotopes': {'density': {'units': 'g/cm3',
#                                       'value': [5.990737703208583,
#                                                 6.110295499877311]},
#                           'file_names': ['V-50.csv', 'V-51.csv'],
#                           'isotopic_ratio': [0.0025, 0.9975],
#                           'list': ['50-V', '51-V'],
#                           'mass': {'units': 'g/mol',
#                                    'value': [49.9471628, 50.9439637]}},
#              'molar_mass': {'units': 'g/mol', 'value': 50.9415}},
#        'atoms_per_cm3': {'V': 7.2230461679122136e+22},
#        'density': {'units': 'g/cm3', 'value': 6.1100000000000003},
#        'elements': ['V'],
#        'stoichiometric_ratio': [1],
#        'thickness': {'units': 'mm', 'value': 0.01}},
#  'Zr': {'Zr': {'density': {'units': 'g/cm3', 'value': 6.506},
#                'isotopes': {'density': {'units': 'g/cm3',
#                                         'value': [6.411909171623695,
#                                                   6.483295255305622,
#                                                   6.554571065625273,
#                                                   6.625992395132859,
#                                                   6.697299949517672,
#                                                   6.768742061367622,
#                                                   6.840077651232132]},
#                             'file_names': ['Zr-90.csv',
#                                            'Zr-91.csv',
#                                            'Zr-92.csv',
#                                            'Zr-93.csv',
#                                            'Zr-94.csv',
#                                            'Zr-95.csv',
#                                            'Zr-96.csv'],
#                             'isotopic_ratio': [0.5145000000000001,
#                                                0.11220000000000001,
#                                                0.17149999999999999,
#                                                0.0,
#                                                0.17379999999999998,
#                                                0.0,
#                                                0.027999999999999997],
#                             'list': ['90-Zr',
#                                      '91-Zr',
#                                      '92-Zr',
#                                      '93-Zr',
#                                      '94-Zr',
#                                      '95-Zr',
#                                      '96-Zr'],
#                             'mass': {'units': 'g/mol',
#                                      'value': [89.9047037,
#                                                90.905645,
#                                                91.9050401,
#                                                92.9064756,
#                                                93.9063158,
#                                                94.9080427,
#                                                95.908276]}},
#                'molar_mass': {'units': 'g/mol', 'value': 91.224}},
#         'atoms_per_cm3': {'Zr': 4.2949276961810489e+22},
#         'density': {'units': 'g/cm3', 'value': 6.5060000000000002},
#         'elements': ['Zr'],
#         'stoichiometric_ratio': [1],
#         'thickness': {'units': 'mm', 'value': 1}}}

# %%
o_reso.plot(mixed=False,
            all_elements=True,
            all_isotopes=False,
            y_axis='sigma',
            x_axis='energy',
           x_in_log=True,
           y_in_log=True)
