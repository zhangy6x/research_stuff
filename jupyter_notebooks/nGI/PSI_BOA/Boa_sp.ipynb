# %%
import numpy as np

# %%
boa = np.loadtxt('./Boa_sp.txt')

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(5,4))
plt.plot(boa[:, 0], boa[:, 1])
plt.xlabel('Wavelength ($\AA$)')
plt.title('Boa spectrum')
plt.tight_layout()
